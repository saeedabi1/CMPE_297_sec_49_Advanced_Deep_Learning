# %% [markdown]
# # **Assignment 1 : Part 2 - Mirsaeid Abolghasemi**

# %% [markdown]
# ## Semi supervised learnign assignment
# Pick an appropriate problem domain for semi supervised  learning for which a small data set is readily available, Implement and submit a proper colab with proper ablation study (with various tunings) using tensorboard  for semi supervised  learning.

# %%
import numpy as np
import pandas as pd
import os, time, re
import pickle, gzip
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import matplotlib as mpl
# %matplotlib inline
'''Data Prep and Model Evaluation'''
from sklearn import preprocessing as pp
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import StratifiedKFold 
from sklearn.metrics import log_loss
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import roc_curve, auc, roc_auc_score
import lightgbm as lgb
import tensorflow as tf
import keras
from keras import backend as K
from keras.models import Sequential, Model
from keras.layers import Activation, Dense, Dropout
from keras.layers import BatchNormalization, Input, Lambda
from keras import regularizers
from keras.losses import mse, binary_crossentropy
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !wget 'https://media.githubusercontent.com/media/aapatel09/handson-unsupervised-learning/master/datasets/credit_card_data/credit_card.csv'
# Out:
# --2020-09-07 16:49:33--  https://media.githubusercontent.com/media/aapatel09/handson-unsupervised-learning/master/datasets/credit_card_data/credit_card.csv
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 150828752 (144M) [text/plain]
# Saving to: ‘credit_card.csv’
#
# credit_card.csv     100%[===================>] 143.84M   117MB/s    in 1.2s
#
# 2020-09-07 16:49:42 (117 MB/s) - ‘credit_card.csv’ saved [150828752/150828752]

# %%
# Load the data
#current_path = os.getcwd()
#file = os.path.sep.join(['', 'credit_card.csv'])

data = pd.read_csv('credit_card.csv')

# %%
data
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %%
dataX = data.copy().drop(['Class','Time'],axis=1)
dataY = data['Class'].copy()

# Scale data
featuresToScale = dataX.columns
sX = pp.StandardScaler(copy=True, with_mean=True, with_std=True)
dataX.loc[:,featuresToScale] = sX.fit_transform(dataX[featuresToScale])

# Split into train and test
X_train, X_test, y_train, y_test = \
    train_test_split(dataX, dataY, test_size=0.33, \
                     random_state=2018, stratify=dataY)

# %%
# Drop 95% of the labels from the training set
toDrop = y_train[y_train==1].sample(frac=0.90,random_state=2018)
X_train.drop(labels=toDrop.index,inplace=True)
y_train.drop(labels=toDrop.index,inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
def anomalyScores(originalDF, reducedDF):
    loss = np.sum((np.array(originalDF) - \
                   np.array(reducedDF))**2, axis=1)
    loss = pd.Series(data=loss,index=originalDF.index)
    loss = (loss-np.min(loss))/(np.max(loss)-np.min(loss))
    return loss

# %%
def plotResults(trueLabels, anomalyScores, returnPreds = False):
    preds = pd.concat([trueLabels, anomalyScores], axis=1)
    preds.columns = ['trueLabel', 'anomalyScore']
    precision, recall, thresholds = \
        precision_recall_curve(preds['trueLabel'], \
                               preds['anomalyScore'])
    average_precision = average_precision_score( \
                        preds['trueLabel'], preds['anomalyScore'])
    
    plt.step(recall, precision, color='k', alpha=0.7, where='post')
    plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    
    plt.title('Precision-Recall curve: Average Precision = \
        {0:0.2f}'.format(average_precision))

    fpr, tpr, thresholds = roc_curve(preds['trueLabel'], \
                                     preds['anomalyScore'])
    areaUnderROC = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
    plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic: Area under the \
        curve = {0:0.2f}'.format(areaUnderROC))
    plt.legend(loc="lower right")
    plt.show()
    
    if returnPreds==True:
        return preds, average_precision

# %%
def precisionAnalysis(df, column, threshold):
    df.sort_values(by=column, ascending=False, inplace=True)
    threshold_value = threshold*df.trueLabel.sum()
    i = 0
    j = 0
    while i < threshold_value+1:
        if df.iloc[j]["trueLabel"]==1:
            i += 1
        j += 1
    return df, i/j

# %%
k_fold = StratifiedKFold(n_splits=5,shuffle=True,random_state=2018)

# %% [markdown]
# ### Supervised Learning Section

# %%
params_lightGB = {
    'task': 'train',
    'application':'binary',
    'num_class':1,
    'boosting': 'gbdt',
    'objective': 'binary',
    'metric': 'binary_logloss',
    'metric_freq':50,
    'is_training_metric':False,
    'max_depth':4,
    'num_leaves': 31,
    'learning_rate': 0.01,
    'feature_fraction': 1.0,
    'bagging_fraction': 1.0,
    'bagging_freq': 0,
    'bagging_seed': 2018,
    'verbose': 0,
    'num_threads':16
}

# %% [markdown]
# **Printing Training Log Loss**
#
# **Printing CV Log Loss**
#
# **Printing LightGBM Gradient Boosting Log Loss**

# %%
trainingScores = []
cvScores = []
predictionsBasedOnKFolds = pd.DataFrame(data=[], index=y_train.index, \
                                        columns=['prediction'])

for train_index, cv_index in k_fold.split(np.zeros(len(X_train)), \
                                          y_train.ravel()):
    X_train_fold, X_cv_fold = X_train.iloc[train_index,:], \
        X_train.iloc[cv_index,:]
    y_train_fold, y_cv_fold = y_train.iloc[train_index], \
        y_train.iloc[cv_index]
    
    lgb_train = lgb.Dataset(X_train_fold, y_train_fold)
    lgb_eval = lgb.Dataset(X_cv_fold, y_cv_fold, reference=lgb_train)
    gbm = lgb.train(params_lightGB, lgb_train, num_boost_round=2000,
                   valid_sets=lgb_eval, early_stopping_rounds=200)
    
    loglossTraining = log_loss(y_train_fold, gbm.predict(X_train_fold, \
                                num_iteration=gbm.best_iteration))
    trainingScores.append(loglossTraining)
    
    predictionsBasedOnKFolds.loc[X_cv_fold.index,'prediction'] = \
        gbm.predict(X_cv_fold, num_iteration=gbm.best_iteration) 
    loglossCV = log_loss(y_cv_fold, \
        predictionsBasedOnKFolds.loc[X_cv_fold.index,'prediction'])
    cvScores.append(loglossCV)
    
    print('Training Log Loss: ', loglossTraining)
    print('CV Log Loss: ', loglossCV)
    
loglossLightGBMGradientBoosting = log_loss(y_train, \
        predictionsBasedOnKFolds.loc[:,'prediction'])
print('LightGBM Gradient Boosting Log Loss: ', \
        loglossLightGBMGradientBoosting)
# Out:
# [1]	valid_0's binary_logloss: 0.00328814
# Training until validation scores don't improve for 200 rounds.
# [2]	valid_0's binary_logloss: 0.00501798
# [3]	valid_0's binary_logloss: 0.0113596
# [4]	valid_0's binary_logloss: 0.0134411
# [5]	valid_0's binary_logloss: 0.0120885
# [6]	valid_0's binary_logloss: 0.0118795
# [7]	valid_0's binary_logloss: 0.0123715
# [8]	valid_0's binary_logloss: 0.0112126
# [9]	valid_0's binary_logloss: 0.0111943
# [10]	valid_0's binary_logloss: 0.0110223
# [11]	valid_0's binary_logloss: 0.0119001
# [12]	valid_0's binary_logloss: 0.011144
# [13]	valid_0's binary_logloss: 0.0108834
# [14]	valid_0's binary_logloss: 0.0103315
# [15]	valid_0's binary_logloss: 0.010241
# [16]	valid_0's binary_logloss: 0.0102127
# [17]	valid_0's binary_logloss: 0.0101784
# [18]	valid_0's binary_logloss: 0.0101528
# [19]	valid_0's binary_logloss: 0.0103359
# [20]	valid_0's binary_logloss: 0.0103066
# [21]	valid_0's binary_logloss: 0.010272
# [22]	valid_0's binary_logloss: 0.0102553
# [23]	valid_0's binary_logloss: 0.0102284
# [24]	valid_0's binary_logloss: 0.0101999
# [25]	valid_0's binary_logloss: 0.0101708
# [26]	valid_0's binary_logloss: 0.0101422
# [27]	valid_0's binary_logloss: 0.0101145
# [28]	valid_0's binary_logloss: 0.0100878
# [29]	valid_0's binary_logloss: 0.0100715
# [30]	valid_0's binary_logloss: 0.0100496
# [31]	valid_0's binary_logloss: 0.0100357
# [32]	valid_0's binary_logloss: 0.010022
# [33]	valid_0's binary_logloss: 0.0100088
# [34]	valid_0's binary_logloss: 0.00999144
# [35]	valid_0's binary_logloss: 0.00997328
# [36]	valid_0's binary_logloss: 0.00995904
# [37]	valid_0's binary_logloss: 0.00997461
# [38]	valid_0's binary_logloss: 0.00996111
# [39]	valid_0's binary_logloss: 0.00994666
# [40]	valid_0's binary_logloss: 0.00993506
# [41]	valid_0's binary_logloss: 0.00992195
# [42]	valid_0's binary_logloss: 0.00991095
# [43]	valid_0's binary_logloss: 0.00989715
# [44]	valid_0's binary_logloss: 0.00988804
# [45]	valid_0's binary_logloss: 0.00987843
# [46]	valid_0's binary_logloss: 0.00986861
# [47]	valid_0's binary_logloss: 0.00985978
# [48]	valid_0's binary_logloss: 0.00984969
# [49]	valid_0's binary_logloss: 0.00985428
# [50]	valid_0's binary_logloss: 0.0098461
# [51]	valid_0's binary_logloss: 0.00983854
# [52]	valid_0's binary_logloss: 0.00983125
# [53]	valid_0's binary_logloss: 0.00982309
# [54]	valid_0's binary_logloss: 0.00981569
# [55]	valid_0's binary_logloss: 0.00980803
# [56]	valid_0's binary_logloss: 0.00979966
# [57]	valid_0's binary_logloss: 0.00979062
# [58]	valid_0's binary_logloss: 0.00978366
# [59]	valid_0's binary_logloss: 0.00977624
# [60]	valid_0's binary_logloss: 0.00976819
# [61]	valid_0's binary_logloss: 0.00976601
# [62]	valid_0's binary_logloss: 0.00975886
# [63]	valid_0's binary_logloss: 0.0097528
# [64]	valid_0's binary_logloss: 0.009746
# [65]	valid_0's binary_logloss: 0.00974001
# [66]	valid_0's binary_logloss: 0.00973335
# [67]	valid_0's binary_logloss: 0.0097256
# [68]	valid_0's binary_logloss: 0.00972017
# [69]	valid_0's binary_logloss: 0.00971426
# [70]	valid_0's binary_logloss: 0.00970894
# [71]	valid_0's binary_logloss: 0.00970374
# [72]	valid_0's binary_logloss: 0.00969931
# [73]	valid_0's binary_logloss: 0.00969423
# [74]	valid_0's binary_logloss: 0.00968931
# [75]	valid_0's binary_logloss: 0.00968435
# [76]	valid_0's binary_logloss: 0.00967894
# [77]	valid_0's binary_logloss: 0.00967355
# [78]	valid_0's binary_logloss: 0.00966877
# [79]	valid_0's binary_logloss: 0.00966359
# [80]	valid_0's binary_logloss: 0.00965897
# [81]	valid_0's binary_logloss: 0.00965453
# [82]	valid_0's binary_logloss: 0.00964888
# [83]	valid_0's binary_logloss: 0.00965337
# [84]	valid_0's binary_logloss: 0.00964959
# [85]	valid_0's binary_logloss: 0.00965173
# [86]	valid_0's binary_logloss: 0.00964633
# [87]	valid_0's binary_logloss: 0.00964196
# [88]	valid_0's binary_logloss: 0.00964289
# [89]	valid_0's binary_logloss: 0.00963825
# [90]	valid_0's binary_logloss: 0.00966405
# [91]	valid_0's binary_logloss: 0.00966048
# [92]	valid_0's binary_logloss: 0.00966213
# [93]	valid_0's binary_logloss: 0.00966032
# [94]	valid_0's binary_logloss: 0.00965999
# [95]	valid_0's binary_logloss: 0.00965708
# [96]	valid_0's binary_logloss: 0.00965511
# [97]	valid_0's binary_logloss: 0.0096519
# [98]	valid_0's binary_logloss: 0.0096487
# [99]	valid_0's binary_logloss: 0.00976537
# [100]	valid_0's binary_logloss: 0.00975966
# [101]	valid_0's binary_logloss: 0.00975427
# [102]	valid_0's binary_logloss: 0.00975318
# [103]	valid_0's binary_logloss: 0.00974905
# [104]	valid_0's binary_logloss: 0.00974477
# [105]	valid_0's binary_logloss: 0.0097408
# [106]	valid_0's binary_logloss: 0.00973666
# [107]	valid_0's binary_logloss: 0.00973092
# [108]	valid_0's binary_logloss: 0.00972698
# [109]	valid_0's binary_logloss: 0.00972581
# [110]	valid_0's binary_logloss: 0.00972037
# [111]	valid_0's binary_logloss: 0.00971597
# [112]	valid_0's binary_logloss: 0.00970964
# [113]	valid_0's binary_logloss: 0.00970541
# [114]	valid_0's binary_logloss: 0.00970198
# [115]	valid_0's binary_logloss: 0.00969812
# [116]	valid_0's binary_logloss: 0.00962838
# [117]	valid_0's binary_logloss: 0.00962438
# [118]	valid_0's binary_logloss: 0.00952611
# [119]	valid_0's binary_logloss: 0.00957779
# [120]	valid_0's binary_logloss: 0.00967437
# [121]	valid_0's binary_logloss: 0.00969184
# [122]	valid_0's binary_logloss: 0.00968998
# [123]	valid_0's binary_logloss: 0.00970125
# [124]	valid_0's binary_logloss: 0.00971038
# [125]	valid_0's binary_logloss: 0.0097086
# [126]	valid_0's binary_logloss: 0.00970643
# [127]	valid_0's binary_logloss: 0.00970239
# [128]	valid_0's binary_logloss: 0.00969497
# [129]	valid_0's binary_logloss: 0.00969219
# [130]	valid_0's binary_logloss: 0.00968777
# [131]	valid_0's binary_logloss: 0.00968471
# [132]	valid_0's binary_logloss: 0.0096816
# [133]	valid_0's binary_logloss: 0.0096784
# [134]	valid_0's binary_logloss: 0.009672
# [135]	valid_0's binary_logloss: 0.00966675
# [136]	valid_0's binary_logloss: 0.00966167
# [137]	valid_0's binary_logloss: 0.00965487
# [138]	valid_0's binary_logloss: 0.00964961
# [139]	valid_0's binary_logloss: 0.00964066
# [140]	valid_0's binary_logloss: 0.00963419
# [141]	valid_0's binary_logloss: 0.00962909
# [142]	valid_0's binary_logloss: 0.00962409
# [143]	valid_0's binary_logloss: 0.0096182
# [144]	valid_0's binary_logloss: 0.00961327
# [145]	valid_0's binary_logloss: 0.00960844
# [146]	valid_0's binary_logloss: 0.00960283
# [147]	valid_0's binary_logloss: 0.00959818
# [148]	valid_0's binary_logloss: 0.00959403
# [149]	valid_0's binary_logloss: 0.00958488
# [150]	valid_0's binary_logloss: 0.00958083
# [151]	valid_0's binary_logloss: 0.0095764
# [152]	valid_0's binary_logloss: 0.00957119
# [153]	valid_0's binary_logloss: 0.00956682
# [154]	valid_0's binary_logloss: 0.00956257
# [155]	valid_0's binary_logloss: 0.00955777
# [156]	valid_0's binary_logloss: 0.00955362
# [157]	valid_0's binary_logloss: 0.00954994
# [158]	valid_0's binary_logloss: 0.0095418
# [159]	valid_0's binary_logloss: 0.00953801
# [160]	valid_0's binary_logloss: 0.00953309
# [161]	valid_0's binary_logloss: 0.00953012
# [162]	valid_0's binary_logloss: 0.00952552
# [163]	valid_0's binary_logloss: 0.00952176
# [164]	valid_0's binary_logloss: 0.009517
# [165]	valid_0's binary_logloss: 0.00951237
# [166]	valid_0's binary_logloss: 0.00950907
# [167]	valid_0's binary_logloss: 0.00950545
# [168]	valid_0's binary_logloss: 0.00950094
# [169]	valid_0's binary_logloss: 0.00949779
# [170]	valid_0's binary_logloss: 0.00949338
# [171]	valid_0's binary_logloss: 0.00948873
# [172]	valid_0's binary_logloss: 0.00948516
# [173]	valid_0's binary_logloss: 0.00948086
# [174]	valid_0's binary_logloss: 0.00947675
# [175]	valid_0's binary_logloss: 0.00947254
# [176]	valid_0's binary_logloss: 0.00946813
# [177]	valid_0's binary_logloss: 0.00946504
# [178]	valid_0's binary_logloss: 0.00946093
# [179]	valid_0's binary_logloss: 0.00945707
# [180]	valid_0's binary_logloss: 0.00945358
# [181]	valid_0's binary_logloss: 0.00944959
# [182]	valid_0's binary_logloss: 0.00944588
# [183]	valid_0's binary_logloss: 0.00944196
# [184]	valid_0's binary_logloss: 0.00943904
# [185]	valid_0's binary_logloss: 0.00943501
# [186]	valid_0's binary_logloss: 0.00942918
# [187]	valid_0's binary_logloss: 0.00942744
# [188]	valid_0's binary_logloss: 0.00942185
# [189]	valid_0's binary_logloss: 0.0094209
# [190]	valid_0's binary_logloss: 0.00941468
# [191]	valid_0's binary_logloss: 0.00941318
# [192]	valid_0's binary_logloss: 0.00941164
# [193]	valid_0's binary_logloss: 0.00940553
# [194]	valid_0's binary_logloss: 0.00940476
# [195]	valid_0's binary_logloss: 0.00939803
# [196]	valid_0's binary_logloss: 0.0093973
# [197]	valid_0's binary_logloss: 0.00939095
# [198]	valid_0's binary_logloss: 0.00938776
# [199]	valid_0's binary_logloss: 0.00938722
# [200]	valid_0's binary_logloss: 0.00938129
# [201]	valid_0's binary_logloss: 0.00938015
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.00328814
# Training Log Loss:  0.002931231218128015
# CV Log Loss:  0.0032881388005420696
# [1]	valid_0's binary_logloss: 0.002832
# Training until validation scores don't improve for 200 rounds.
# [2]	valid_0's binary_logloss: 0.00159326
# [3]	valid_0's binary_logloss: 0.00109952
# [4]	valid_0's binary_logloss: 0.00128771
# [5]	valid_0's binary_logloss: 0.00128578
# [6]	valid_0's binary_logloss: 0.00128359
# [7]	valid_0's binary_logloss: 0.00128148
# [8]	valid_0's binary_logloss: 0.00127937
# [9]	valid_0's binary_logloss: 0.00127729
# [10]	valid_0's binary_logloss: 0.00127519
# [11]	valid_0's binary_logloss: 0.00127372
# [12]	valid_0's binary_logloss: 0.00127193
# [13]	valid_0's binary_logloss: 0.0012701
# [14]	valid_0's binary_logloss: 0.00126843
# [15]	valid_0's binary_logloss: 0.00126657
# [16]	valid_0's binary_logloss: 0.00126488
# [17]	valid_0's binary_logloss: 0.0012634
# [18]	valid_0's binary_logloss: 0.00126182
# [19]	valid_0's binary_logloss: 0.00126033
# [20]	valid_0's binary_logloss: 0.00125897
# [21]	valid_0's binary_logloss: 0.00125602
# [22]	valid_0's binary_logloss: 0.0012533
# [23]	valid_0's binary_logloss: 0.00126054
# [24]	valid_0's binary_logloss: 0.00125744
# [25]	valid_0's binary_logloss: 0.00125462
# [26]	valid_0's binary_logloss: 0.0012516
# [27]	valid_0's binary_logloss: 0.00124855
# [28]	valid_0's binary_logloss: 0.00124563
# [29]	valid_0's binary_logloss: 0.00124365
# [30]	valid_0's binary_logloss: 0.00124079
# [31]	valid_0's binary_logloss: 0.00123801
# [32]	valid_0's binary_logloss: 0.00123528
# [33]	valid_0's binary_logloss: 0.00123265
# [34]	valid_0's binary_logloss: 0.00123003
# [35]	valid_0's binary_logloss: 0.00122746
# [36]	valid_0's binary_logloss: 0.00122515
# [37]	valid_0's binary_logloss: 0.00122274
# [38]	valid_0's binary_logloss: 0.00122033
# [39]	valid_0's binary_logloss: 0.00121794
# [40]	valid_0's binary_logloss: 0.00121565
# [41]	valid_0's binary_logloss: 0.00121333
# [42]	valid_0's binary_logloss: 0.00121119
# [43]	valid_0's binary_logloss: 0.00120889
# [44]	valid_0's binary_logloss: 0.00120664
# [45]	valid_0's binary_logloss: 0.00120504
# [46]	valid_0's binary_logloss: 0.0012029
# [47]	valid_0's binary_logloss: 0.00120068
# [48]	valid_0's binary_logloss: 0.00119859
# [49]	valid_0's binary_logloss: 0.00119651
# [50]	valid_0's binary_logloss: 0.00119454
# [51]	valid_0's binary_logloss: 0.00119244
# [52]	valid_0's binary_logloss: 0.00119054
# [53]	valid_0's binary_logloss: 0.00118912
# [54]	valid_0's binary_logloss: 0.0011871
# [55]	valid_0's binary_logloss: 0.0011851
# [56]	valid_0's binary_logloss: 0.00118319
# [57]	valid_0's binary_logloss: 0.00118124
# [58]	valid_0's binary_logloss: 0.00117937
# [59]	valid_0's binary_logloss: 0.00117748
# [60]	valid_0's binary_logloss: 0.00117574
# [61]	valid_0's binary_logloss: 0.00117396
# [62]	valid_0's binary_logloss: 0.00117221
# [63]	valid_0's binary_logloss: 0.00117038
# [64]	valid_0's binary_logloss: 0.0011687
# [65]	valid_0's binary_logloss: 0.00116691
# [66]	valid_0's binary_logloss: 0.00116529
# [67]	valid_0's binary_logloss: 0.00116463
# [68]	valid_0's binary_logloss: 0.00116301
# [69]	valid_0's binary_logloss: 0.00116194
# [70]	valid_0's binary_logloss: 0.00116065
# [71]	valid_0's binary_logloss: 0.00115957
# [72]	valid_0's binary_logloss: 0.00115922
# [73]	valid_0's binary_logloss: 0.00115819
# [74]	valid_0's binary_logloss: 0.00115716
# [75]	valid_0's binary_logloss: 0.00115616
# [76]	valid_0's binary_logloss: 0.00115516
# [77]	valid_0's binary_logloss: 0.00115347
# [78]	valid_0's binary_logloss: 0.00115249
# [79]	valid_0's binary_logloss: 0.00115048
# [80]	valid_0's binary_logloss: 0.00114952
# [81]	valid_0's binary_logloss: 0.00114819
# [82]	valid_0's binary_logloss: 0.00114558
# [83]	valid_0's binary_logloss: 0.00114301
# [84]	valid_0's binary_logloss: 0.00114045
# [85]	valid_0's binary_logloss: 0.0011379
# [86]	valid_0's binary_logloss: 0.0011354
# [87]	valid_0's binary_logloss: 0.00113289
# [88]	valid_0's binary_logloss: 0.00113042
# [89]	valid_0's binary_logloss: 0.00112965
# [90]	valid_0's binary_logloss: 0.00112719
# [91]	valid_0's binary_logloss: 0.00112644
# [92]	valid_0's binary_logloss: 0.00112569
# [93]	valid_0's binary_logloss: 0.00112331
# [94]	valid_0's binary_logloss: 0.00112259
# [95]	valid_0's binary_logloss: 0.00112189
# [96]	valid_0's binary_logloss: 0.00111954
# [97]	valid_0's binary_logloss: 0.00111885
# [98]	valid_0's binary_logloss: 0.00111654
# [99]	valid_0's binary_logloss: 0.00111587
# [100]	valid_0's binary_logloss: 0.00111521
# [101]	valid_0's binary_logloss: 0.00111349
# [102]	valid_0's binary_logloss: 0.00111263
# [103]	valid_0's binary_logloss: 0.001112
# [104]	valid_0's binary_logloss: 0.00111116
# [105]	valid_0's binary_logloss: 0.0011086
# [106]	valid_0's binary_logloss: 0.00110565
# [107]	valid_0's binary_logloss: 0.00110483
# [108]	valid_0's binary_logloss: 0.0011037
# [109]	valid_0's binary_logloss: 0.00110291
# [110]	valid_0's binary_logloss: 0.00110135
# [111]	valid_0's binary_logloss: 0.00110025
# [112]	valid_0's binary_logloss: 0.0010994
# [113]	valid_0's binary_logloss: 0.00109863
# [114]	valid_0's binary_logloss: 0.00109711
# [115]	valid_0's binary_logloss: 0.00109605
# [116]	valid_0's binary_logloss: 0.00109523
# [117]	valid_0's binary_logloss: 0.00109367
# [118]	valid_0's binary_logloss: 0.00109251
# [119]	valid_0's binary_logloss: 0.00109171
# [120]	valid_0's binary_logloss: 0.00109055
# [121]	valid_0's binary_logloss: 0.00108982
# [122]	valid_0's binary_logloss: 0.00108866
# [123]	valid_0's binary_logloss: 0.00108753
# [124]	valid_0's binary_logloss: 0.00108675
# [125]	valid_0's binary_logloss: 0.00108584
# [126]	valid_0's binary_logloss: 0.00108471
# [127]	valid_0's binary_logloss: 0.00108338
# [128]	valid_0's binary_logloss: 0.00108209
# [129]	valid_0's binary_logloss: 0.00108002
# [130]	valid_0's binary_logloss: 0.00107873
# [131]	valid_0's binary_logloss: 0.00107745
# [132]	valid_0's binary_logloss: 0.00107548
# [133]	valid_0's binary_logloss: 0.00107435
# [134]	valid_0's binary_logloss: 0.00107309
# [135]	valid_0's binary_logloss: 0.00107185
# [136]	valid_0's binary_logloss: 0.00106985
# [137]	valid_0's binary_logloss: 0.00106875
# [138]	valid_0's binary_logloss: 0.00106753
# [139]	valid_0's binary_logloss: 0.00106554
# [140]	valid_0's binary_logloss: 0.00106435
# [141]	valid_0's binary_logloss: 0.00106327
# [142]	valid_0's binary_logloss: 0.00106138
# [143]	valid_0's binary_logloss: 0.0010602
# [144]	valid_0's binary_logloss: 0.00105902
# [145]	valid_0's binary_logloss: 0.00105798
# [146]	valid_0's binary_logloss: 0.00105606
# [147]	valid_0's binary_logloss: 0.00105491
# [148]	valid_0's binary_logloss: 0.00105377
# [149]	valid_0's binary_logloss: 0.00105188
# [150]	valid_0's binary_logloss: 0.00105082
# [151]	valid_0's binary_logloss: 0.00105039
# [152]	valid_0's binary_logloss: 0.00104938
# [153]	valid_0's binary_logloss: 0.00104839
# [154]	valid_0's binary_logloss: 0.00104694
# [155]	valid_0's binary_logloss: 0.00104511
# [156]	valid_0's binary_logloss: 0.00104412
# [157]	valid_0's binary_logloss: 0.00104235
# [158]	valid_0's binary_logloss: 0.00104094
# [159]	valid_0's binary_logloss: 0.00103997
# [160]	valid_0's binary_logloss: 0.00103816
# [161]	valid_0's binary_logloss: 0.00103637
# [162]	valid_0's binary_logloss: 0.00103542
# [163]	valid_0's binary_logloss: 0.00103403
# [164]	valid_0's binary_logloss: 0.00103231
# [165]	valid_0's binary_logloss: 0.00103138
# [166]	valid_0's binary_logloss: 0.00103
# [167]	valid_0's binary_logloss: 0.00102827
# [168]	valid_0's binary_logloss: 0.00102659
# [169]	valid_0's binary_logloss: 0.00102566
# [170]	valid_0's binary_logloss: 0.00102431
# [171]	valid_0's binary_logloss: 0.00102371
# [172]	valid_0's binary_logloss: 0.00102312
# [173]	valid_0's binary_logloss: 0.00102225
# [174]	valid_0's binary_logloss: 0.0010217
# [175]	valid_0's binary_logloss: 0.0010208
# [176]	valid_0's binary_logloss: 0.00102026
# [177]	valid_0's binary_logloss: 0.00101973
# [178]	valid_0's binary_logloss: 0.00101887
# [179]	valid_0's binary_logloss: 0.00101835
# [180]	valid_0's binary_logloss: 0.00101758
# [181]	valid_0's binary_logloss: 0.00101707
# [182]	valid_0's binary_logloss: 0.00101656
# [183]	valid_0's binary_logloss: 0.00101533
# [184]	valid_0's binary_logloss: 0.00101484
# [185]	valid_0's binary_logloss: 0.00101435
# [186]	valid_0's binary_logloss: 0.00101314
# [187]	valid_0's binary_logloss: 0.00101265
# [188]	valid_0's binary_logloss: 0.00101146
# [189]	valid_0's binary_logloss: 0.00101098
# [190]	valid_0's binary_logloss: 0.00101052
# [191]	valid_0's binary_logloss: 0.00100933
# [192]	valid_0's binary_logloss: 0.00100887
# [193]	valid_0's binary_logloss: 0.0010077
# [194]	valid_0's binary_logloss: 0.00100725
# [195]	valid_0's binary_logloss: 0.00100681
# [196]	valid_0's binary_logloss: 0.00100565
# [197]	valid_0's binary_logloss: 0.00100522
# [198]	valid_0's binary_logloss: 0.00100407
# [199]	valid_0's binary_logloss: 0.00100361
# [200]	valid_0's binary_logloss: 0.00100318
# [201]	valid_0's binary_logloss: 0.00100205
# [202]	valid_0's binary_logloss: 0.0010016
# [203]	valid_0's binary_logloss: 0.00100119
# [204]	valid_0's binary_logloss: 0.00100042
# [205]	valid_0's binary_logloss: 0.000999982
# [206]	valid_0's binary_logloss: 0.000998871
# [207]	valid_0's binary_logloss: 0.000998476
# [208]	valid_0's binary_logloss: 0.000998051
# [209]	valid_0's binary_logloss: 0.00099753
# [210]	valid_0's binary_logloss: 0.000996436
# [211]	valid_0's binary_logloss: 0.000995925
# [212]	valid_0's binary_logloss: 0.000994841
# [213]	valid_0's binary_logloss: 0.000994433
# [214]	valid_0's binary_logloss: 0.000993932
# [215]	valid_0's binary_logloss: 0.000992563
# [216]	valid_0's binary_logloss: 0.000991228
# [217]	valid_0's binary_logloss: 0.000989882
# [218]	valid_0's binary_logloss: 0.000988825
# [219]	valid_0's binary_logloss: 0.000988333
# [220]	valid_0's binary_logloss: 0.00098702
# [221]	valid_0's binary_logloss: 0.000985664
# [222]	valid_0's binary_logloss: 0.000985195
# [223]	valid_0's binary_logloss: 0.000983897
# [224]	valid_0's binary_logloss: 0.000982557
# [225]	valid_0's binary_logloss: 0.000982068
# [226]	valid_0's binary_logloss: 0.000980786
# [227]	valid_0's binary_logloss: 0.00097949
# [228]	valid_0's binary_logloss: 0.00097817
# [229]	valid_0's binary_logloss: 0.000977166
# [230]	valid_0's binary_logloss: 0.000976716
# [231]	valid_0's binary_logloss: 0.000975639
# [232]	valid_0's binary_logloss: 0.000974342
# [233]	valid_0's binary_logloss: 0.000973082
# [234]	valid_0's binary_logloss: 0.000972487
# [235]	valid_0's binary_logloss: 0.000972029
# [236]	valid_0's binary_logloss: 0.000971595
# [237]	valid_0's binary_logloss: 0.000970984
# [238]	valid_0's binary_logloss: 0.000970568
# [239]	valid_0's binary_logloss: 0.000969961
# [240]	valid_0's binary_logloss: 0.000969301
# [241]	valid_0's binary_logloss: 0.000968082
# [242]	valid_0's binary_logloss: 0.000967653
# [243]	valid_0's binary_logloss: 0.000967253
# [244]	valid_0's binary_logloss: 0.000966661
# [245]	valid_0's binary_logloss: 0.000966018
# [246]	valid_0's binary_logloss: 0.000965603
# [247]	valid_0's binary_logloss: 0.000965019
# [248]	valid_0's binary_logloss: 0.000964406
# [249]	valid_0's binary_logloss: 0.000963217
# [250]	valid_0's binary_logloss: 0.00096284
# [251]	valid_0's binary_logloss: 0.00096227
# [252]	valid_0's binary_logloss: 0.000961648
# [253]	valid_0's binary_logloss: 0.000961252
# [254]	valid_0's binary_logloss: 0.000960893
# [255]	valid_0's binary_logloss: 0.000960328
# [256]	valid_0's binary_logloss: 0.000959719
# [257]	valid_0's binary_logloss: 0.00095916
# [258]	valid_0's binary_logloss: 0.000958807
# [259]	valid_0's binary_logloss: 0.000957653
# [260]	valid_0's binary_logloss: 0.000957057
# [261]	valid_0's binary_logloss: 0.000955861
# [262]	valid_0's binary_logloss: 0.000955313
# [263]	valid_0's binary_logloss: 0.000954974
# [264]	valid_0's binary_logloss: 0.000954429
# [265]	valid_0's binary_logloss: 0.00095385
# [266]	valid_0's binary_logloss: 0.000952562
# [267]	valid_0's binary_logloss: 0.00095128
# [268]	valid_0's binary_logloss: 0.000950741
# [269]	valid_0's binary_logloss: 0.000949466
# [270]	valid_0's binary_logloss: 0.000948932
# [271]	valid_0's binary_logloss: 0.000948279
# [272]	valid_0's binary_logloss: 0.000947686
# [273]	valid_0's binary_logloss: 0.000947097
# [274]	valid_0's binary_logloss: 0.000946451
# [275]	valid_0's binary_logloss: 0.000945922
# [276]	valid_0's binary_logloss: 0.00094534
# [277]	valid_0's binary_logloss: 0.000944701
# [278]	valid_0's binary_logloss: 0.000944125
# [279]	valid_0's binary_logloss: 0.000943551
# [280]	valid_0's binary_logloss: 0.000942919
# [281]	valid_0's binary_logloss: 0.000942398
# [282]	valid_0's binary_logloss: 0.000941831
# [283]	valid_0's binary_logloss: 0.000941205
# [284]	valid_0's binary_logloss: 0.000940644
# [285]	valid_0's binary_logloss: 0.000940105
# [286]	valid_0's binary_logloss: 0.000939485
# [287]	valid_0's binary_logloss: 0.000939594
# [288]	valid_0's binary_logloss: 0.000939083
# [289]	valid_0's binary_logloss: 0.000938468
# [290]	valid_0's binary_logloss: 0.000937957
# [291]	valid_0's binary_logloss: 0.000938076
# [292]	valid_0's binary_logloss: 0.000937529
# [293]	valid_0's binary_logloss: 0.000936985
# [294]	valid_0's binary_logloss: 0.000937109
# [295]	valid_0's binary_logloss: 0.000936602
# [296]	valid_0's binary_logloss: 0.000936064
# [297]	valid_0's binary_logloss: 0.00093619
# [298]	valid_0's binary_logloss: 0.000935657
# [299]	valid_0's binary_logloss: 0.000935157
# [300]	valid_0's binary_logloss: 0.000934628
# [301]	valid_0's binary_logloss: 0.000934765
# [302]	valid_0's binary_logloss: 0.000934241
# [303]	valid_0's binary_logloss: 0.000934399
# [304]	valid_0's binary_logloss: 0.000934524
# [305]	valid_0's binary_logloss: 0.000933902
# [306]	valid_0's binary_logloss: 0.000934029
# [307]	valid_0's binary_logloss: 0.000933412
# [308]	valid_0's binary_logloss: 0.000932918
# [309]	valid_0's binary_logloss: 0.000933066
# [310]	valid_0's binary_logloss: 0.000933202
# [311]	valid_0's binary_logloss: 0.000932615
# [312]	valid_0's binary_logloss: 0.000932135
# [313]	valid_0's binary_logloss: 0.000932274
# [314]	valid_0's binary_logloss: 0.00093167
# [315]	valid_0's binary_logloss: 0.000931069
# [316]	valid_0's binary_logloss: 0.000930472
# [317]	valid_0's binary_logloss: 0.000930618
# [318]	valid_0's binary_logloss: 0.000930069
# [319]	valid_0's binary_logloss: 0.000930217
# [320]	valid_0's binary_logloss: 0.000929713
# [321]	valid_0's binary_logloss: 0.000929126
# [322]	valid_0's binary_logloss: 0.000929278
# [323]	valid_0's binary_logloss: 0.000928654
# [324]	valid_0's binary_logloss: 0.000928034
# [325]	valid_0's binary_logloss: 0.000927539
# [326]	valid_0's binary_logloss: 0.000926961
# [327]	valid_0's binary_logloss: 0.000926347
# [328]	valid_0's binary_logloss: 0.000926531
# [329]	valid_0's binary_logloss: 0.00092596
# [330]	valid_0's binary_logloss: 0.000925463
# [331]	valid_0's binary_logloss: 0.000924908
# [332]	valid_0's binary_logloss: 0.000924343
# [333]	valid_0's binary_logloss: 0.000923781
# [334]	valid_0's binary_logloss: 0.000923286
# [335]	valid_0's binary_logloss: 0.000922738
# [336]	valid_0's binary_logloss: 0.000922183
# [337]	valid_0's binary_logloss: 0.000921629
# [338]	valid_0's binary_logloss: 0.000921135
# [339]	valid_0's binary_logloss: 0.000920596
# [340]	valid_0's binary_logloss: 0.000920048
# [341]	valid_0's binary_logloss: 0.000919535
# [342]	valid_0's binary_logloss: 0.00091899
# [343]	valid_0's binary_logloss: 0.00091846
# [344]	valid_0's binary_logloss: 0.000917586
# [345]	valid_0's binary_logloss: 0.000917788
# [346]	valid_0's binary_logloss: 0.000917262
# [347]	valid_0's binary_logloss: 0.000916776
# [348]	valid_0's binary_logloss: 0.000916242
# [349]	valid_0's binary_logloss: 0.000915711
# [350]	valid_0's binary_logloss: 0.000914849
# [351]	valid_0's binary_logloss: 0.000914332
# [352]	valid_0's binary_logloss: 0.000913758
# [353]	valid_0's binary_logloss: 0.000913968
# [354]	valid_0's binary_logloss: 0.000913113
# [355]	valid_0's binary_logloss: 0.000912602
# [356]	valid_0's binary_logloss: 0.000912109
# [357]	valid_0's binary_logloss: 0.000911591
# [358]	valid_0's binary_logloss: 0.000911087
# [359]	valid_0's binary_logloss: 0.00091024
# [360]	valid_0's binary_logloss: 0.000910457
# [361]	valid_0's binary_logloss: 0.000909956
# [362]	valid_0's binary_logloss: 0.000909127
# [363]	valid_0's binary_logloss: 0.000908617
# [364]	valid_0's binary_logloss: 0.000908837
# [365]	valid_0's binary_logloss: 0.000908332
# [366]	valid_0's binary_logloss: 0.000907853
# [367]	valid_0's binary_logloss: 0.000907359
# [368]	valid_0's binary_logloss: 0.000906539
# [369]	valid_0's binary_logloss: 0.00090604
# [370]	valid_0's binary_logloss: 0.00090557
# [371]	valid_0's binary_logloss: 0.000905083
# [372]	valid_0's binary_logloss: 0.000904588
# [373]	valid_0's binary_logloss: 0.000904095
# [374]	valid_0's binary_logloss: 0.000903283
# [375]	valid_0's binary_logloss: 0.000903134
# [376]	valid_0's binary_logloss: 0.000903364
# [377]	valid_0's binary_logloss: 0.000902877
# [378]	valid_0's binary_logloss: 0.00090207
# [379]	valid_0's binary_logloss: 0.000901852
# [380]	valid_0's binary_logloss: 0.000901386
# [381]	valid_0's binary_logloss: 0.000901238
# [382]	valid_0's binary_logloss: 0.000900756
# [383]	valid_0's binary_logloss: 0.000899956
# [384]	valid_0's binary_logloss: 0.000899804
# [385]	valid_0's binary_logloss: 0.000900041
# [386]	valid_0's binary_logloss: 0.000898893
# [387]	valid_0's binary_logloss: 0.000898098
# [388]	valid_0's binary_logloss: 0.000897621
# [389]	valid_0's binary_logloss: 0.000897861
# [390]	valid_0's binary_logloss: 0.000896708
# [391]	valid_0's binary_logloss: 0.000896253
# [392]	valid_0's binary_logloss: 0.000895111
# [393]	valid_0's binary_logloss: 0.000894657
# [394]	valid_0's binary_logloss: 0.000893522
# [395]	valid_0's binary_logloss: 0.000892379
# [396]	valid_0's binary_logloss: 0.000891597
# [397]	valid_0's binary_logloss: 0.000890458
# [398]	valid_0's binary_logloss: 0.000890009
# [399]	valid_0's binary_logloss: 0.000888882
# [400]	valid_0's binary_logloss: 0.000888429
# [401]	valid_0's binary_logloss: 0.000887296
# [402]	valid_0's binary_logloss: 0.000887073
# [403]	valid_0's binary_logloss: 0.000886538
# [404]	valid_0's binary_logloss: 0.000886069
# [405]	valid_0's binary_logloss: 0.000885535
# [406]	valid_0's binary_logloss: 0.000884764
# [407]	valid_0's binary_logloss: 0.000884281
# [408]	valid_0's binary_logloss: 0.0008838
# [409]	valid_0's binary_logloss: 0.000883322
# [410]	valid_0's binary_logloss: 0.000882795
# [411]	valid_0's binary_logloss: 0.00088232
# [412]	valid_0's binary_logloss: 0.000881796
# [413]	valid_0's binary_logloss: 0.000881324
# [414]	valid_0's binary_logloss: 0.000880855
# [415]	valid_0's binary_logloss: 0.000880335
# [416]	valid_0's binary_logloss: 0.000879868
# [417]	valid_0's binary_logloss: 0.000879351
# [418]	valid_0's binary_logloss: 0.000878957
# [419]	valid_0's binary_logloss: 0.000878565
# [420]	valid_0's binary_logloss: 0.000878175
# [421]	valid_0's binary_logloss: 0.000877715
# [422]	valid_0's binary_logloss: 0.000877328
# [423]	valid_0's binary_logloss: 0.000877084
# [424]	valid_0's binary_logloss: 0.000876699
# [425]	valid_0's binary_logloss: 0.000876316
# [426]	valid_0's binary_logloss: 0.000875958
# [427]	valid_0's binary_logloss: 0.000875586
# [428]	valid_0's binary_logloss: 0.000875585
# [429]	valid_0's binary_logloss: 0.000875207
# [430]	valid_0's binary_logloss: 0.000875209
# [431]	valid_0's binary_logloss: 0.000874833
# [432]	valid_0's binary_logloss: 0.000874836
# [433]	valid_0's binary_logloss: 0.000874471
# [434]	valid_0's binary_logloss: 0.000874477
# [435]	valid_0's binary_logloss: 0.00087409
# [436]	valid_0's binary_logloss: 0.00087372
# [437]	valid_0's binary_logloss: 0.00087351
# [438]	valid_0's binary_logloss: 0.000873127
# [439]	valid_0's binary_logloss: 0.000872767
# [440]	valid_0's binary_logloss: 0.00087227
# [441]	valid_0's binary_logloss: 0.000871883
# [442]	valid_0's binary_logloss: 0.000871895
# [443]	valid_0's binary_logloss: 0.0008714
# [444]	valid_0's binary_logloss: 0.000871023
# [445]	valid_0's binary_logloss: 0.000870637
# [446]	valid_0's binary_logloss: 0.000870144
# [447]	valid_0's binary_logloss: 0.000869915
# [448]	valid_0's binary_logloss: 0.000869424
# [449]	valid_0's binary_logloss: 0.00086905
# [450]	valid_0's binary_logloss: 0.000868699
# [451]	valid_0's binary_logloss: 0.000868211
# [452]	valid_0's binary_logloss: 0.00086784
# [453]	valid_0's binary_logloss: 0.000867613
# [454]	valid_0's binary_logloss: 0.000867127
# [455]	valid_0's binary_logloss: 0.00086676
# [456]	valid_0's binary_logloss: 0.000866276
# [457]	valid_0's binary_logloss: 0.000865998
# [458]	valid_0's binary_logloss: 0.000865773
# [459]	valid_0's binary_logloss: 0.000865291
# [460]	valid_0's binary_logloss: 0.000864909
# [461]	valid_0's binary_logloss: 0.000864429
# [462]	valid_0's binary_logloss: 0.000864079
# [463]	valid_0's binary_logloss: 0.000863738
# [464]	valid_0's binary_logloss: 0.000863766
# [465]	valid_0's binary_logloss: 0.000863491
# [466]	valid_0's binary_logloss: 0.000863521
# [467]	valid_0's binary_logloss: 0.00086285
# [468]	valid_0's binary_logloss: 0.000862492
# [469]	valid_0's binary_logloss: 0.000861824
# [470]	valid_0's binary_logloss: 0.00086148
# [471]	valid_0's binary_logloss: 0.000861243
# [472]	valid_0's binary_logloss: 0.000860908
# [473]	valid_0's binary_logloss: 0.000860674
# [474]	valid_0's binary_logloss: 0.000860709
# [475]	valid_0's binary_logloss: 0.000860369
# [476]	valid_0's binary_logloss: 0.000860037
# [477]	valid_0's binary_logloss: 0.000860074
# [478]	valid_0's binary_logloss: 0.000859685
# [479]	valid_0's binary_logloss: 0.000859518
# [480]	valid_0's binary_logloss: 0.000859183
# [481]	valid_0's binary_logloss: 0.000859223
# [482]	valid_0's binary_logloss: 0.000858569
# [483]	valid_0's binary_logloss: 0.000858242
# [484]	valid_0's binary_logloss: 0.000858019
# [485]	valid_0's binary_logloss: 0.000857368
# [486]	valid_0's binary_logloss: 0.000857037
# [487]	valid_0's binary_logloss: 0.000856388
# [488]	valid_0's binary_logloss: 0.000856064
# [489]	valid_0's binary_logloss: 0.000856107
# [490]	valid_0's binary_logloss: 0.00085546
# [491]	valid_0's binary_logloss: 0.000855132
# [492]	valid_0's binary_logloss: 0.000854487
# [493]	valid_0's binary_logloss: 0.000854162
# [494]	valid_0's binary_logloss: 0.000854542
# [495]	valid_0's binary_logloss: 0.000853899
# [496]	valid_0's binary_logloss: 0.000853581
# [497]	valid_0's binary_logloss: 0.000852939
# [498]	valid_0's binary_logloss: 0.000853318
# [499]	valid_0's binary_logloss: 0.000852997
# [500]	valid_0's binary_logloss: 0.000852587
# [501]	valid_0's binary_logloss: 0.000851948
# [502]	valid_0's binary_logloss: 0.00085131
# [503]	valid_0's binary_logloss: 0.000850673
# [504]	valid_0's binary_logloss: 0.000850355
# [505]	valid_0's binary_logloss: 0.000849721
# [506]	valid_0's binary_logloss: 0.000849087
# [507]	valid_0's binary_logloss: 0.0008488
# [508]	valid_0's binary_logloss: 0.00084849
# [509]	valid_0's binary_logloss: 0.000849232
# [510]	valid_0's binary_logloss: 0.000848948
# [511]	valid_0's binary_logloss: 0.000848318
# [512]	valid_0's binary_logloss: 0.000848034
# [513]	valid_0's binary_logloss: 0.000847752
# [514]	valid_0's binary_logloss: 0.000847125
# [515]	valid_0's binary_logloss: 0.000846894
# [516]	valid_0's binary_logloss: 0.00084628
# [517]	valid_0's binary_logloss: 0.000846051
# [518]	valid_0's binary_logloss: 0.000845771
# [519]	valid_0's binary_logloss: 0.000845542
# [520]	valid_0's binary_logloss: 0.000844938
# [521]	valid_0's binary_logloss: 0.000844328
# [522]	valid_0's binary_logloss: 0.000844102
# [523]	valid_0's binary_logloss: 0.000843824
# [524]	valid_0's binary_logloss: 0.00084318
# [525]	valid_0's binary_logloss: 0.000842955
# [526]	valid_0's binary_logloss: 0.000842653
# [527]	valid_0's binary_logloss: 0.000842351
# [528]	valid_0's binary_logloss: 0.000841754
# [529]	valid_0's binary_logloss: 0.000841749
# [530]	valid_0's binary_logloss: 0.000841449
# [531]	valid_0's binary_logloss: 0.000840855
# [532]	valid_0's binary_logloss: 0.000840557
# [533]	valid_0's binary_logloss: 0.000839967
# [534]	valid_0's binary_logloss: 0.000839744
# [535]	valid_0's binary_logloss: 0.000839448
# [536]	valid_0's binary_logloss: 0.000838859
# [537]	valid_0's binary_logloss: 0.000838565
# [538]	valid_0's binary_logloss: 0.000837981
# [539]	valid_0's binary_logloss: 0.000837688
# [540]	valid_0's binary_logloss: 0.000837105
# [541]	valid_0's binary_logloss: 0.0008371
# [542]	valid_0's binary_logloss: 0.000836795
# [543]	valid_0's binary_logloss: 0.000836217
# [544]	valid_0's binary_logloss: 0.000836212
# [545]	valid_0's binary_logloss: 0.000835634
# [546]	valid_0's binary_logloss: 0.000835415
# [547]	valid_0's binary_logloss: 0.000834842
# [548]	valid_0's binary_logloss: 0.000834838
# [549]	valid_0's binary_logloss: 0.000834535
# [550]	valid_0's binary_logloss: 0.000833965
# [551]	valid_0's binary_logloss: 0.000833748
# [552]	valid_0's binary_logloss: 0.000833178
# [553]	valid_0's binary_logloss: 0.000833174
# [554]	valid_0's binary_logloss: 0.000832073
# [555]	valid_0's binary_logloss: 0.000831772
# [556]	valid_0's binary_logloss: 0.000830673
# [557]	valid_0's binary_logloss: 0.000829578
# [558]	valid_0's binary_logloss: 0.000829364
# [559]	valid_0's binary_logloss: 0.000828271
# [560]	valid_0's binary_logloss: 0.000827972
# [561]	valid_0's binary_logloss: 0.000826883
# [562]	valid_0's binary_logloss: 0.000826596
# [563]	valid_0's binary_logloss: 0.000826299
# [564]	valid_0's binary_logloss: 0.000826012
# [565]	valid_0's binary_logloss: 0.000826007
# [566]	valid_0's binary_logloss: 0.000825214
# [567]	valid_0's binary_logloss: 0.000825139
# [568]	valid_0's binary_logloss: 0.000824843
# [569]	valid_0's binary_logloss: 0.000824052
# [570]	valid_0's binary_logloss: 0.000823967
# [571]	valid_0's binary_logloss: 0.000823178
# [572]	valid_0's binary_logloss: 0.000823174
# [573]	valid_0's binary_logloss: 0.000822388
# [574]	valid_0's binary_logloss: 0.000822095
# [575]	valid_0's binary_logloss: 0.00082175
# [576]	valid_0's binary_logloss: 0.000820966
# [577]	valid_0's binary_logloss: 0.000820962
# [578]	valid_0's binary_logloss: 0.000820876
# [579]	valid_0's binary_logloss: 0.000820583
# [580]	valid_0's binary_logloss: 0.000819802
# [581]	valid_0's binary_logloss: 0.000819722
# [582]	valid_0's binary_logloss: 0.000818943
# [583]	valid_0's binary_logloss: 0.000818599
# [584]	valid_0's binary_logloss: 0.000818308
# [585]	valid_0's binary_logloss: 0.00081753
# [586]	valid_0's binary_logloss: 0.000817185
# [587]	valid_0's binary_logloss: 0.000817182
# [588]	valid_0's binary_logloss: 0.000816893
# [589]	valid_0's binary_logloss: 0.000816118
# [590]	valid_0's binary_logloss: 0.000816029
# [591]	valid_0's binary_logloss: 0.000815816
# [592]	valid_0's binary_logloss: 0.000815043
# [593]	valid_0's binary_logloss: 0.000814273
# [594]	valid_0's binary_logloss: 0.000814181
# [595]	valid_0's binary_logloss: 0.000813969
# [596]	valid_0's binary_logloss: 0.0008132
# [597]	valid_0's binary_logloss: 0.000812434
# [598]	valid_0's binary_logloss: 0.000812089
# [599]	valid_0's binary_logloss: 0.000811878
# [600]	valid_0's binary_logloss: 0.000811507
# [601]	valid_0's binary_logloss: 0.000811414
# [602]	valid_0's binary_logloss: 0.000811202
# [603]	valid_0's binary_logloss: 0.000810438
# [604]	valid_0's binary_logloss: 0.00081007
# [605]	valid_0's binary_logloss: 0.000810405
# [606]	valid_0's binary_logloss: 0.00081006
# [607]	valid_0's binary_logloss: 0.000809692
# [608]	valid_0's binary_logloss: 0.000809342
# [609]	valid_0's binary_logloss: 0.000808976
# [610]	valid_0's binary_logloss: 0.000808707
# [611]	valid_0's binary_logloss: 0.000808425
# [612]	valid_0's binary_logloss: 0.00080806
# [613]	valid_0's binary_logloss: 0.000808394
# [614]	valid_0's binary_logloss: 0.000808298
# [615]	valid_0's binary_logloss: 0.000807538
# [616]	valid_0's binary_logloss: 0.000807257
# [617]	valid_0's binary_logloss: 0.000806895
# [618]	valid_0's binary_logloss: 0.000807031
# [619]	valid_0's binary_logloss: 0.000807169
# [620]	valid_0's binary_logloss: 0.000806899
# [621]	valid_0's binary_logloss: 0.000806552
# [622]	valid_0's binary_logloss: 0.000806193
# [623]	valid_0's binary_logloss: 0.000806333
# [624]	valid_0's binary_logloss: 0.000806474
# [625]	valid_0's binary_logloss: 0.000806616
# [626]	valid_0's binary_logloss: 0.000806371
# [627]	valid_0's binary_logloss: 0.000806099
# [628]	valid_0's binary_logloss: 0.000805826
# [629]	valid_0's binary_logloss: 0.000806158
# [630]	valid_0's binary_logloss: 0.000805805
# [631]	valid_0's binary_logloss: 0.000805951
# [632]	valid_0's binary_logloss: 0.000806099
# [633]	valid_0's binary_logloss: 0.00080564
# [634]	valid_0's binary_logloss: 0.000805291
# [635]	valid_0's binary_logloss: 0.000804857
# [636]	valid_0's binary_logloss: 0.000804514
# [637]	valid_0's binary_logloss: 0.000803915
# [638]	valid_0's binary_logloss: 0.000803737
# [639]	valid_0's binary_logloss: 0.000803306
# [640]	valid_0's binary_logloss: 0.000802687
# [641]	valid_0's binary_logloss: 0.000802844
# [642]	valid_0's binary_logloss: 0.000802503
# [643]	valid_0's binary_logloss: 0.000802328
# [644]	valid_0's binary_logloss: 0.000801899
# [645]	valid_0's binary_logloss: 0.000801646
# [646]	valid_0's binary_logloss: 0.00080138
# [647]	valid_0's binary_logloss: 0.00080076
# [648]	valid_0's binary_logloss: 0.00080109
# [649]	valid_0's binary_logloss: 0.000801421
# [650]	valid_0's binary_logloss: 0.000801077
# [651]	valid_0's binary_logloss: 0.00080065
# [652]	valid_0's binary_logloss: 0.000800052
# [653]	valid_0's binary_logloss: 0.000799879
# [654]	valid_0's binary_logloss: 0.00079954
# [655]	valid_0's binary_logloss: 0.000799115
# [656]	valid_0's binary_logloss: 0.00079884
# [657]	valid_0's binary_logloss: 0.000798577
# [658]	valid_0's binary_logloss: 0.000798242
# [659]	valid_0's binary_logloss: 0.000798574
# [660]	valid_0's binary_logloss: 0.000797976
# [661]	valid_0's binary_logloss: 0.000797635
# [662]	valid_0's binary_logloss: 0.000797464
# [663]	valid_0's binary_logloss: 0.000796839
# [664]	valid_0's binary_logloss: 0.000797003
# [665]	valid_0's binary_logloss: 0.000796669
# [666]	valid_0's binary_logloss: 0.000796247
# [667]	valid_0's binary_logloss: 0.000795685
# [668]	valid_0's binary_logloss: 0.000795515
# [669]	valid_0's binary_logloss: 0.000795097
# [670]	valid_0's binary_logloss: 0.000794842
# [671]	valid_0's binary_logloss: 0.000794512
# [672]	valid_0's binary_logloss: 0.000794118
# [673]	valid_0's binary_logloss: 0.000793523
# [674]	valid_0's binary_logloss: 0.000793689
# [675]	valid_0's binary_logloss: 0.000792958
# [676]	valid_0's binary_logloss: 0.000793286
# [677]	valid_0's binary_logloss: 0.000793118
# [678]	valid_0's binary_logloss: 0.000792863
# [679]	valid_0's binary_logloss: 0.000792472
# [680]	valid_0's binary_logloss: 0.00079214
# [681]	valid_0's binary_logloss: 0.000792304
# [682]	valid_0's binary_logloss: 0.000792026
# [683]	valid_0's binary_logloss: 0.000791612
# [684]	valid_0's binary_logloss: 0.000791838
# [685]	valid_0's binary_logloss: 0.000790944
# [686]	valid_0's binary_logloss: 0.000791116
# [687]	valid_0's binary_logloss: 0.000791284
# [688]	valid_0's binary_logloss: 0.000790558
# [689]	valid_0's binary_logloss: 0.00079017
# [690]	valid_0's binary_logloss: 0.000790339
# [691]	valid_0's binary_logloss: 0.000790089
# [692]	valid_0's binary_logloss: 0.00079026
# [693]	valid_0's binary_logloss: 0.000790096
# [694]	valid_0's binary_logloss: 0.000789776
# [695]	valid_0's binary_logloss: 0.00078997
# [696]	valid_0's binary_logloss: 0.000790144
# [697]	valid_0's binary_logloss: 0.000789862
# [698]	valid_0's binary_logloss: 0.000789479
# [699]	valid_0's binary_logloss: 0.000789833
# [700]	valid_0's binary_logloss: 0.000790157
# [701]	valid_0's binary_logloss: 0.000789776
# [702]	valid_0's binary_logloss: 0.000789514
# [703]	valid_0's binary_logloss: 0.000789868
# [704]	valid_0's binary_logloss: 0.000789268
# [705]	valid_0's binary_logloss: 0.000788949
# [706]	valid_0's binary_logloss: 0.000789125
# [707]	valid_0's binary_logloss: 0.000789303
# [708]	valid_0's binary_logloss: 0.000789102
# [709]	valid_0's binary_logloss: 0.000789424
# [710]	valid_0's binary_logloss: 0.000789044
# [711]	valid_0's binary_logloss: 0.000789224
# [712]	valid_0's binary_logloss: 0.000788937
# [713]	valid_0's binary_logloss: 0.000789449
# [714]	valid_0's binary_logloss: 0.000789631
# [715]	valid_0's binary_logloss: 0.000790145
# [716]	valid_0's binary_logloss: 0.000790505
# [717]	valid_0's binary_logloss: 0.000789957
# [718]	valid_0's binary_logloss: 0.000790188
# [719]	valid_0's binary_logloss: 0.000789645
# [720]	valid_0's binary_logloss: 0.000789493
# [721]	valid_0's binary_logloss: 0.000789242
# [722]	valid_0's binary_logloss: 0.000788699
# [723]	valid_0's binary_logloss: 0.000788449
# [724]	valid_0's binary_logloss: 0.000788657
# [725]	valid_0's binary_logloss: 0.000788977
# [726]	valid_0's binary_logloss: 0.000788437
# [727]	valid_0's binary_logloss: 0.000788375
# [728]	valid_0's binary_logloss: 0.000788124
# [729]	valid_0's binary_logloss: 0.000787584
# [730]	valid_0's binary_logloss: 0.000787335
# [731]	valid_0's binary_logloss: 0.000786799
# [732]	valid_0's binary_logloss: 0.000787011
# [733]	valid_0's binary_logloss: 0.00078647
# [734]	valid_0's binary_logloss: 0.000786834
# [735]	valid_0's binary_logloss: 0.000786294
# [736]	valid_0's binary_logloss: 0.000785759
# [737]	valid_0's binary_logloss: 0.000785489
# [738]	valid_0's binary_logloss: 0.000784953
# [739]	valid_0's binary_logloss: 0.000785319
# [740]	valid_0's binary_logloss: 0.000784784
# [741]	valid_0's binary_logloss: 0.000784712
# [742]	valid_0's binary_logloss: 0.000785163
# [743]	valid_0's binary_logloss: 0.000784857
# [744]	valid_0's binary_logloss: 0.000784784
# [745]	valid_0's binary_logloss: 0.000784518
# [746]	valid_0's binary_logloss: 0.000783985
# [747]	valid_0's binary_logloss: 0.000783452
# [748]	valid_0's binary_logloss: 0.000783258
# [749]	valid_0's binary_logloss: 0.000783064
# [750]	valid_0's binary_logloss: 0.000782537
# [751]	valid_0's binary_logloss: 0.000782344
# [752]	valid_0's binary_logloss: 0.000782045
# [753]	valid_0's binary_logloss: 0.000781854
# [754]	valid_0's binary_logloss: 0.000781327
# [755]	valid_0's binary_logloss: 0.000781136
# [756]	valid_0's binary_logloss: 0.000780613
# [757]	valid_0's binary_logloss: 0.000780424
# [758]	valid_0's binary_logloss: 0.000780254
# [759]	valid_0's binary_logloss: 0.000779733
# [760]	valid_0's binary_logloss: 0.000779545
# [761]	valid_0's binary_logloss: 0.00077917
# [762]	valid_0's binary_logloss: 0.000778651
# [763]	valid_0's binary_logloss: 0.000778464
# [764]	valid_0's binary_logloss: 0.000778173
# [765]	valid_0's binary_logloss: 0.000777988
# [766]	valid_0's binary_logloss: 0.000777472
# [767]	valid_0's binary_logloss: 0.000777479
# [768]	valid_0's binary_logloss: 0.000777109
# [769]	valid_0's binary_logloss: 0.000776926
# [770]	valid_0's binary_logloss: 0.000776559
# [771]	valid_0's binary_logloss: 0.000776048
# [772]	valid_0's binary_logloss: 0.000775036
# [773]	valid_0's binary_logloss: 0.00077513
# [774]	valid_0's binary_logloss: 0.000774125
# [775]	valid_0's binary_logloss: 0.000773117
# [776]	valid_0's binary_logloss: 0.000772605
# [777]	valid_0's binary_logloss: 0.000772432
# [778]	valid_0's binary_logloss: 0.000772292
# [779]	valid_0's binary_logloss: 0.000771735
# [780]	valid_0's binary_logloss: 0.000771564
# [781]	valid_0's binary_logloss: 0.000771058
# [782]	valid_0's binary_logloss: 0.000770059
# [783]	valid_0's binary_logloss: 0.000770149
# [784]	valid_0's binary_logloss: 0.000769981
# [785]	valid_0's binary_logloss: 0.000769477
# [786]	valid_0's binary_logloss: 0.000768926
# [787]	valid_0's binary_logloss: 0.000768791
# [788]	valid_0's binary_logloss: 0.000768808
# [789]	valid_0's binary_logloss: 0.000768822
# [790]	valid_0's binary_logloss: 0.000768319
# [791]	valid_0's binary_logloss: 0.000768186
# [792]	valid_0's binary_logloss: 0.000768024
# [793]	valid_0's binary_logloss: 0.000768039
# [794]	valid_0's binary_logloss: 0.000767906
# [795]	valid_0's binary_logloss: 0.000767925
# [796]	valid_0's binary_logloss: 0.000767795
# [797]	valid_0's binary_logloss: 0.000768035
# [798]	valid_0's binary_logloss: 0.000767683
# [799]	valid_0's binary_logloss: 0.0007677
# [800]	valid_0's binary_logloss: 0.000767782
# [801]	valid_0's binary_logloss: 0.000767627
# [802]	valid_0's binary_logloss: 0.000767498
# [803]	valid_0's binary_logloss: 0.000767515
# [804]	valid_0's binary_logloss: 0.000767389
# [805]	valid_0's binary_logloss: 0.000767415
# [806]	valid_0's binary_logloss: 0.000767364
# [807]	valid_0's binary_logloss: 0.000767094
# [808]	valid_0's binary_logloss: 0.000767111
# [809]	valid_0's binary_logloss: 0.000766762
# [810]	valid_0's binary_logloss: 0.000767178
# [811]	valid_0's binary_logloss: 0.000767055
# [812]	valid_0's binary_logloss: 0.000767073
# [813]	valid_0's binary_logloss: 0.000767023
# [814]	valid_0's binary_logloss: 0.000767437
# [815]	valid_0's binary_logloss: 0.000767698
# [816]	valid_0's binary_logloss: 0.000767353
# [817]	valid_0's binary_logloss: 0.00076723
# [818]	valid_0's binary_logloss: 0.00076725
# [819]	valid_0's binary_logloss: 0.000766909
# [820]	valid_0's binary_logloss: 0.000767161
# [821]	valid_0's binary_logloss: 0.000767237
# [822]	valid_0's binary_logloss: 0.000767042
# [823]	valid_0's binary_logloss: 0.000766924
# [824]	valid_0's binary_logloss: 0.000766723
# [825]	valid_0's binary_logloss: 0.000767088
# [826]	valid_0's binary_logloss: 0.000767352
# [827]	valid_0's binary_logloss: 0.000767346
# [828]	valid_0's binary_logloss: 0.000767762
# [829]	valid_0's binary_logloss: 0.000767425
# [830]	valid_0's binary_logloss: 0.000767315
# [831]	valid_0's binary_logloss: 0.00076739
# [832]	valid_0's binary_logloss: 0.00076727
# [833]	valid_0's binary_logloss: 0.00076678
# [834]	valid_0's binary_logloss: 0.000766672
# [835]	valid_0's binary_logloss: 0.00076649
# [836]	valid_0's binary_logloss: 0.000766002
# [837]	valid_0's binary_logloss: 0.000765853
# [838]	valid_0's binary_logloss: 0.000765699
# [839]	valid_0's binary_logloss: 0.000765592
# [840]	valid_0's binary_logloss: 0.000765664
# [841]	valid_0's binary_logloss: 0.000765694
# [842]	valid_0's binary_logloss: 0.000765209
# [843]	valid_0's binary_logloss: 0.000765103
# [844]	valid_0's binary_logloss: 0.000765081
# [845]	valid_0's binary_logloss: 0.00076493
# [846]	valid_0's binary_logloss: 0.000765197
# [847]	valid_0's binary_logloss: 0.000764716
# [848]	valid_0's binary_logloss: 0.000764604
# [849]	valid_0's binary_logloss: 0.000764972
# [850]	valid_0's binary_logloss: 0.000764788
# [851]	valid_0's binary_logloss: 0.000764859
# [852]	valid_0's binary_logloss: 0.000764922
# [853]	valid_0's binary_logloss: 0.000764773
# [854]	valid_0's binary_logloss: 0.000765041
# [855]	valid_0's binary_logloss: 0.000764563
# [856]	valid_0's binary_logloss: 0.000764608
# [857]	valid_0's binary_logloss: 0.000764284
# [858]	valid_0's binary_logloss: 0.000764264
# [859]	valid_0's binary_logloss: 0.000764679
# [860]	valid_0's binary_logloss: 0.000764748
# [861]	valid_0's binary_logloss: 0.000764638
# [862]	valid_0's binary_logloss: 0.000765007
# [863]	valid_0's binary_logloss: 0.000764861
# [864]	valid_0's binary_logloss: 0.00076493
# [865]	valid_0's binary_logloss: 0.000764454
# [866]	valid_0's binary_logloss: 0.000764211
# [867]	valid_0's binary_logloss: 0.000764581
# [868]	valid_0's binary_logloss: 0.000764437
# [869]	valid_0's binary_logloss: 0.000763964
# [870]	valid_0's binary_logloss: 0.000763622
# [871]	valid_0's binary_logloss: 0.000763292
# [872]	valid_0's binary_logloss: 0.000763359
# [873]	valid_0's binary_logloss: 0.000763019
# [874]	valid_0's binary_logloss: 0.000762779
# [875]	valid_0's binary_logloss: 0.000763049
# [876]	valid_0's binary_logloss: 0.000762783
# [877]	valid_0's binary_logloss: 0.000763151
# [878]	valid_0's binary_logloss: 0.000763422
# [879]	valid_0's binary_logloss: 0.000763835
# [880]	valid_0's binary_logloss: 0.000763649
# [881]	valid_0's binary_logloss: 0.000763545
# [882]	valid_0's binary_logloss: 0.000763203
# [883]	valid_0's binary_logloss: 0.000762873
# [884]	valid_0's binary_logloss: 0.000762944
# [885]	valid_0's binary_logloss: 0.000762604
# [886]	valid_0's binary_logloss: 0.00076241
# [887]	valid_0's binary_logloss: 0.000762713
# [888]	valid_0's binary_logloss: 0.000762909
# [889]	valid_0's binary_logloss: 0.000763312
# [890]	valid_0's binary_logloss: 0.000763209
# [891]	valid_0's binary_logloss: 0.000763021
# [892]	valid_0's binary_logloss: 0.000762691
# [893]	valid_0's binary_logloss: 0.000762217
# [894]	valid_0's binary_logloss: 0.000761875
# [895]	valid_0's binary_logloss: 0.000762088
# [896]	valid_0's binary_logloss: 0.000761614
# [897]	valid_0's binary_logloss: 0.000761273
# [898]	valid_0's binary_logloss: 0.000760931
# [899]	valid_0's binary_logloss: 0.000761276
# [900]	valid_0's binary_logloss: 0.000761626
# [901]	valid_0's binary_logloss: 0.000761285
# ...
# [919]	valid_0's binary_logloss: 0.00215363
# [920]	valid_0's binary_logloss: 0.00215336
# [921]	valid_0's binary_logloss: 0.0021534
# [922]	valid_0's binary_logloss: 0.00215329
# [923]	valid_0's binary_logloss: 0.00215379
# [924]	valid_0's binary_logloss: 0.00215383
# [925]	valid_0's binary_logloss: 0.00215356
# [926]	valid_0's binary_logloss: 0.00215344
# [927]	valid_0's binary_logloss: 0.00215351
# [928]	valid_0's binary_logloss: 0.00215401
# [929]	valid_0's binary_logloss: 0.00215393
# [930]	valid_0's binary_logloss: 0.00215397
# [931]	valid_0's binary_logloss: 0.00215386
# [932]	valid_0's binary_logloss: 0.00215358
# [933]	valid_0's binary_logloss: 0.00215365
# [934]	valid_0's binary_logloss: 0.00215355
# [935]	valid_0's binary_logloss: 0.00215344
# [936]	valid_0's binary_logloss: 0.00215317
# [937]	valid_0's binary_logloss: 0.00215321
# [938]	valid_0's binary_logloss: 0.0021531
# [939]	valid_0's binary_logloss: 0.0021536
# [940]	valid_0's binary_logloss: 0.00215367
# [941]	valid_0's binary_logloss: 0.0021534
# [942]	valid_0's binary_logloss: 0.00215313
# [943]	valid_0's binary_logloss: 0.00215302
# [944]	valid_0's binary_logloss: 0.00215306
# [945]	valid_0's binary_logloss: 0.00215304
# [946]	valid_0's binary_logloss: 0.00215276
# [947]	valid_0's binary_logloss: 0.0021528
# [948]	valid_0's binary_logloss: 0.0021527
# [949]	valid_0's binary_logloss: 0.00215274
# [950]	valid_0's binary_logloss: 0.00215324
# [951]	valid_0's binary_logloss: 0.00215321
# [952]	valid_0's binary_logloss: 0.0021531
# [953]	valid_0's binary_logloss: 0.00215317
# [954]	valid_0's binary_logloss: 0.00215308
# [955]	valid_0's binary_logloss: 0.00215327
# [956]	valid_0's binary_logloss: 0.00215316
# [957]	valid_0's binary_logloss: 0.00215366
# [958]	valid_0's binary_logloss: 0.00215371
# [959]	valid_0's binary_logloss: 0.00215367
# [960]	valid_0's binary_logloss: 0.00215417
# [961]	valid_0's binary_logloss: 0.00215407
# [962]	valid_0's binary_logloss: 0.00215411
# [963]	valid_0's binary_logloss: 0.00215401
# [964]	valid_0's binary_logloss: 0.00215391
# [965]	valid_0's binary_logloss: 0.00215398
# [966]	valid_0's binary_logloss: 0.00215395
# [967]	valid_0's binary_logloss: 0.00215392
# [968]	valid_0's binary_logloss: 0.00215396
# [969]	valid_0's binary_logloss: 0.00215386
# [970]	valid_0's binary_logloss: 0.00215399
# [971]	valid_0's binary_logloss: 0.00215397
# [972]	valid_0's binary_logloss: 0.00215394
# [973]	valid_0's binary_logloss: 0.00215398
# [974]	valid_0's binary_logloss: 0.00215388
# [975]	valid_0's binary_logloss: 0.00215392
# [976]	valid_0's binary_logloss: 0.00215442
# [977]	valid_0's binary_logloss: 0.00215491
# [978]	valid_0's binary_logloss: 0.00215481
# [979]	valid_0's binary_logloss: 0.00215486
# [980]	valid_0's binary_logloss: 0.00215487
# [981]	valid_0's binary_logloss: 0.00215477
# [982]	valid_0's binary_logloss: 0.00215467
# [983]	valid_0's binary_logloss: 0.00215474
# [984]	valid_0's binary_logloss: 0.00215471
# [985]	valid_0's binary_logloss: 0.00215521
# [986]	valid_0's binary_logloss: 0.00215511
# [987]	valid_0's binary_logloss: 0.00215515
# [988]	valid_0's binary_logloss: 0.00215512
# [989]	valid_0's binary_logloss: 0.00215516
# [990]	valid_0's binary_logloss: 0.00215516
# [991]	valid_0's binary_logloss: 0.0021553
# [992]	valid_0's binary_logloss: 0.00215579
# [993]	valid_0's binary_logloss: 0.00215581
# [994]	valid_0's binary_logloss: 0.00215571
# [995]	valid_0's binary_logloss: 0.00215575
# [996]	valid_0's binary_logloss: 0.00215566
# [997]	valid_0's binary_logloss: 0.00215556
# [998]	valid_0's binary_logloss: 0.00215553
# [999]	valid_0's binary_logloss: 0.00215557
# [1000]	valid_0's binary_logloss: 0.00215554
# [1001]	valid_0's binary_logloss: 0.0021556
# [1002]	valid_0's binary_logloss: 0.00215609
# [1003]	valid_0's binary_logloss: 0.00215577
# [1004]	valid_0's binary_logloss: 0.00215544
# [1005]	valid_0's binary_logloss: 0.00215568
# [1006]	valid_0's binary_logloss: 0.00215575
# [1007]	valid_0's binary_logloss: 0.00215565
# [1008]	valid_0's binary_logloss: 0.00215533
# [1009]	valid_0's binary_logloss: 0.00215557
# [1010]	valid_0's binary_logloss: 0.00215525
# [1011]	valid_0's binary_logloss: 0.00215548
# [1012]	valid_0's binary_logloss: 0.00215551
# [1013]	valid_0's binary_logloss: 0.00215548
# [1014]	valid_0's binary_logloss: 0.00215552
# [1015]	valid_0's binary_logloss: 0.00215558
# [1016]	valid_0's binary_logloss: 0.00215562
# [1017]	valid_0's binary_logloss: 0.00215605
# [1018]	valid_0's binary_logloss: 0.00215581
# [1019]	valid_0's binary_logloss: 0.0021558
# [1020]	valid_0's binary_logloss: 0.00215577
# [1021]	valid_0's binary_logloss: 0.00215578
# [1022]	valid_0's binary_logloss: 0.00215594
# [1023]	valid_0's binary_logloss: 0.0021557
# [1024]	valid_0's binary_logloss: 0.00215575
# [1025]	valid_0's binary_logloss: 0.00215551
# [1026]	valid_0's binary_logloss: 0.00215548
# [1027]	valid_0's binary_logloss: 0.00215553
# [1028]	valid_0's binary_logloss: 0.00215554
# [1029]	valid_0's binary_logloss: 0.00215522
# [1030]	valid_0's binary_logloss: 0.00215546
# [1031]	valid_0's binary_logloss: 0.00215564
# [1032]	valid_0's binary_logloss: 0.0021554
# [1033]	valid_0's binary_logloss: 0.00215517
# [1034]	valid_0's binary_logloss: 0.00215517
# [1035]	valid_0's binary_logloss: 0.00215524
# [1036]	valid_0's binary_logloss: 0.00215522
# [1037]	valid_0's binary_logloss: 0.00215519
# [1038]	valid_0's binary_logloss: 0.00215525
# [1039]	valid_0's binary_logloss: 0.00215515
# [1040]	valid_0's binary_logloss: 0.00215501
# [1041]	valid_0's binary_logloss: 0.00215477
# [1042]	valid_0's binary_logloss: 0.00215478
# [1043]	valid_0's binary_logloss: 0.00215454
# [1044]	valid_0's binary_logloss: 0.00215445
# [1045]	valid_0's binary_logloss: 0.00215421
# [1046]	valid_0's binary_logloss: 0.00215426
# [1047]	valid_0's binary_logloss: 0.00215402
# [1048]	valid_0's binary_logloss: 0.00215426
# [1049]	valid_0's binary_logloss: 0.00215445
# [1050]	valid_0's binary_logloss: 0.00215422
# [1051]	valid_0's binary_logloss: 0.00215398
# [1052]	valid_0's binary_logloss: 0.00215396
# [1053]	valid_0's binary_logloss: 0.00215397
# [1054]	valid_0's binary_logloss: 0.00215388
# [1055]	valid_0's binary_logloss: 0.00215364
# [1056]	valid_0's binary_logloss: 0.00215332
# [1057]	valid_0's binary_logloss: 0.00215356
# [1058]	valid_0's binary_logloss: 0.00215365
# [1059]	valid_0's binary_logloss: 0.00215389
# [1060]	valid_0's binary_logloss: 0.0021537
# [1061]	valid_0's binary_logloss: 0.00215393
# [1062]	valid_0's binary_logloss: 0.00215391
# [1063]	valid_0's binary_logloss: 0.00215414
# [1064]	valid_0's binary_logloss: 0.00215438
# [1065]	valid_0's binary_logloss: 0.00215458
# [1066]	valid_0's binary_logloss: 0.00215455
# [1067]	valid_0's binary_logloss: 0.00215479
# [1068]	valid_0's binary_logloss: 0.0021548
# [1069]	valid_0's binary_logloss: 0.00215504
# [1070]	valid_0's binary_logloss: 0.00215513
# [1071]	valid_0's binary_logloss: 0.00215536
# [1072]	valid_0's binary_logloss: 0.00215534
# [1073]	valid_0's binary_logloss: 0.00215558
# [1074]	valid_0's binary_logloss: 0.00215567
# [1075]	valid_0's binary_logloss: 0.0021559
# [1076]	valid_0's binary_logloss: 0.00215612
# [1077]	valid_0's binary_logloss: 0.00215613
# [1078]	valid_0's binary_logloss: 0.00215589
# [1079]	valid_0's binary_logloss: 0.00215613
# Early stopping, best iteration is:
# [879]	valid_0's binary_logloss: 0.0021516
# Training Log Loss:  1.0299213681436855e-06
# CV Log Loss:  0.0021515999376705156
# [1]	valid_0's binary_logloss: 0.00333634
# Training until validation scores don't improve for 200 rounds.
# [2]	valid_0's binary_logloss: 0.00279683
# [3]	valid_0's binary_logloss: 0.00339353
# [4]	valid_0's binary_logloss: 0.00355312
# [5]	valid_0's binary_logloss: 0.00407757
# [6]	valid_0's binary_logloss: 0.00394302
# [7]	valid_0's binary_logloss: 0.00388888
# [8]	valid_0's binary_logloss: 0.00385497
# [9]	valid_0's binary_logloss: 0.00382738
# [10]	valid_0's binary_logloss: 0.00379453
# [11]	valid_0's binary_logloss: 0.00377587
# [12]	valid_0's binary_logloss: 0.00375775
# [13]	valid_0's binary_logloss: 0.003787
# [14]	valid_0's binary_logloss: 0.00664874
# [15]	valid_0's binary_logloss: 0.00662544
# [16]	valid_0's binary_logloss: 0.0075635
# [17]	valid_0's binary_logloss: 0.00564655
# [18]	valid_0's binary_logloss: 0.00538621
# [19]	valid_0's binary_logloss: 0.00526879
# [20]	valid_0's binary_logloss: 0.0050437
# [21]	valid_0's binary_logloss: 0.00502543
# [22]	valid_0's binary_logloss: 0.00493041
# [23]	valid_0's binary_logloss: 0.00490952
# [24]	valid_0's binary_logloss: 0.00488827
# [25]	valid_0's binary_logloss: 0.00477181
# [26]	valid_0's binary_logloss: 0.00472306
# [27]	valid_0's binary_logloss: 0.00470474
# [28]	valid_0's binary_logloss: 0.00468804
# [29]	valid_0's binary_logloss: 0.00454176
# [30]	valid_0's binary_logloss: 0.00457988
# [31]	valid_0's binary_logloss: 0.00459196
# [32]	valid_0's binary_logloss: 0.00458482
# [33]	valid_0's binary_logloss: 0.00457469
# [34]	valid_0's binary_logloss: 0.00455915
# [35]	valid_0's binary_logloss: 0.00454555
# [36]	valid_0's binary_logloss: 0.00453252
# [37]	valid_0's binary_logloss: 0.00452032
# [38]	valid_0's binary_logloss: 0.004507
# [39]	valid_0's binary_logloss: 0.00449693
# [40]	valid_0's binary_logloss: 0.00447705
# [41]	valid_0's binary_logloss: 0.00446852
# [42]	valid_0's binary_logloss: 0.00445581
# [43]	valid_0's binary_logloss: 0.00444504
# [44]	valid_0's binary_logloss: 0.00443278
# [45]	valid_0's binary_logloss: 0.00442032
# [46]	valid_0's binary_logloss: 0.00441001
# [47]	valid_0's binary_logloss: 0.00439881
# [48]	valid_0's binary_logloss: 0.00441076
# [49]	valid_0's binary_logloss: 0.00439914
# [50]	valid_0's binary_logloss: 0.00438404
# [51]	valid_0's binary_logloss: 0.00436947
# [52]	valid_0's binary_logloss: 0.00435848
# [53]	valid_0's binary_logloss: 0.00434494
# [54]	valid_0's binary_logloss: 0.00433641
# [55]	valid_0's binary_logloss: 0.00432824
# [56]	valid_0's binary_logloss: 0.00431459
# [57]	valid_0's binary_logloss: 0.00430634
# [58]	valid_0's binary_logloss: 0.00429614
# [59]	valid_0's binary_logloss: 0.00428587
# [60]	valid_0's binary_logloss: 0.0042777
# [61]	valid_0's binary_logloss: 0.00426804
# [62]	valid_0's binary_logloss: 0.00425961
# [63]	valid_0's binary_logloss: 0.00425056
# [64]	valid_0's binary_logloss: 0.00424068
# [65]	valid_0's binary_logloss: 0.00423104
# [66]	valid_0's binary_logloss: 0.00422154
# [67]	valid_0's binary_logloss: 0.00421263
# [68]	valid_0's binary_logloss: 0.00420536
# [69]	valid_0's binary_logloss: 0.00419643
# [70]	valid_0's binary_logloss: 0.00418785
# [71]	valid_0's binary_logloss: 0.00417825
# [72]	valid_0's binary_logloss: 0.00416934
# [73]	valid_0's binary_logloss: 0.00416132
# [74]	valid_0's binary_logloss: 0.00417267
# [75]	valid_0's binary_logloss: 0.00418497
# [76]	valid_0's binary_logloss: 0.00419049
# [77]	valid_0's binary_logloss: 0.00418655
# [78]	valid_0's binary_logloss: 0.00418695
# [79]	valid_0's binary_logloss: 0.00418369
# [80]	valid_0's binary_logloss: 0.00417931
# [81]	valid_0's binary_logloss: 0.00417197
# [82]	valid_0's binary_logloss: 0.00416819
# [83]	valid_0's binary_logloss: 0.00416621
# [84]	valid_0's binary_logloss: 0.00416201
# [85]	valid_0's binary_logloss: 0.00415575
# [86]	valid_0's binary_logloss: 0.00414906
# [87]	valid_0's binary_logloss: 0.00414492
# [88]	valid_0's binary_logloss: 0.00413891
# [89]	valid_0's binary_logloss: 0.00413215
# [90]	valid_0's binary_logloss: 0.00412597
# [91]	valid_0's binary_logloss: 0.0041221
# [92]	valid_0's binary_logloss: 0.00411629
# [93]	valid_0's binary_logloss: 0.00411054
# [94]	valid_0's binary_logloss: 0.00410466
# [95]	valid_0's binary_logloss: 0.00409889
# [96]	valid_0's binary_logloss: 0.00409374
# [97]	valid_0's binary_logloss: 0.00409037
# [98]	valid_0's binary_logloss: 0.00408455
# [99]	valid_0's binary_logloss: 0.00408028
# [100]	valid_0's binary_logloss: 0.00407462
# [101]	valid_0's binary_logloss: 0.00406914
# [102]	valid_0's binary_logloss: 0.00406376
# [103]	valid_0's binary_logloss: 0.00405958
# [104]	valid_0's binary_logloss: 0.00405434
# [105]	valid_0's binary_logloss: 0.00404909
# [106]	valid_0's binary_logloss: 0.0040432
# [107]	valid_0's binary_logloss: 0.00403728
# [108]	valid_0's binary_logloss: 0.00403151
# [109]	valid_0's binary_logloss: 0.0040258
# [110]	valid_0's binary_logloss: 0.00402114
# [111]	valid_0's binary_logloss: 0.00401609
# [112]	valid_0's binary_logloss: 0.00401046
# [113]	valid_0's binary_logloss: 0.0040051
# [114]	valid_0's binary_logloss: 0.00400096
# [115]	valid_0's binary_logloss: 0.00399566
# [116]	valid_0's binary_logloss: 0.00399145
# [117]	valid_0's binary_logloss: 0.00398642
# [118]	valid_0's binary_logloss: 0.00398158
# [119]	valid_0's binary_logloss: 0.0039769
# [120]	valid_0's binary_logloss: 0.00397389
# [121]	valid_0's binary_logloss: 0.00396934
# [122]	valid_0's binary_logloss: 0.00396469
# [123]	valid_0's binary_logloss: 0.00396018
# [124]	valid_0's binary_logloss: 0.00395632
# [125]	valid_0's binary_logloss: 0.00395142
# [126]	valid_0's binary_logloss: 0.00394657
# [127]	valid_0's binary_logloss: 0.00394175
# [128]	valid_0's binary_logloss: 0.00393698
# [129]	valid_0's binary_logloss: 0.00393224
# [130]	valid_0's binary_logloss: 0.00392753
# [131]	valid_0's binary_logloss: 0.00392288
# [132]	valid_0's binary_logloss: 0.00391824
# [133]	valid_0's binary_logloss: 0.00391394
# [134]	valid_0's binary_logloss: 0.0039098
# [135]	valid_0's binary_logloss: 0.00390566
# [136]	valid_0's binary_logloss: 0.00390119
# [137]	valid_0's binary_logloss: 0.00389675
# [138]	valid_0's binary_logloss: 0.00389254
# [139]	valid_0's binary_logloss: 0.00387876
# [140]	valid_0's binary_logloss: 0.00387375
# [141]	valid_0's binary_logloss: 0.00386336
# [142]	valid_0's binary_logloss: 0.00385848
# [143]	valid_0's binary_logloss: 0.00399601
# [144]	valid_0's binary_logloss: 0.00399297
# [145]	valid_0's binary_logloss: 0.00398975
# [146]	valid_0's binary_logloss: 0.00398411
# [147]	valid_0's binary_logloss: 0.00398072
# [148]	valid_0's binary_logloss: 0.00397514
# [149]	valid_0's binary_logloss: 0.00396928
# [150]	valid_0's binary_logloss: 0.00396348
# [151]	valid_0's binary_logloss: 0.00395774
# [152]	valid_0's binary_logloss: 0.00395206
# [153]	valid_0's binary_logloss: 0.00394644
# [154]	valid_0's binary_logloss: 0.00394087
# [155]	valid_0's binary_logloss: 0.00393503
# [156]	valid_0's binary_logloss: 0.00392924
# [157]	valid_0's binary_logloss: 0.00392378
# [158]	valid_0's binary_logloss: 0.00391805
# [159]	valid_0's binary_logloss: 0.00391237
# [160]	valid_0's binary_logloss: 0.00390658
# [161]	valid_0's binary_logloss: 0.00390084
# [162]	valid_0's binary_logloss: 0.00389543
# [163]	valid_0's binary_logloss: 0.00388979
# [164]	valid_0's binary_logloss: 0.00388419
# [165]	valid_0's binary_logloss: 0.00387892
# [166]	valid_0's binary_logloss: 0.00387341
# [167]	valid_0's binary_logloss: 0.00386795
# [168]	valid_0's binary_logloss: 0.00386254
# [169]	valid_0's binary_logloss: 0.00385745
# [170]	valid_0's binary_logloss: 0.00385212
# [171]	valid_0's binary_logloss: 0.00384683
# [172]	valid_0's binary_logloss: 0.00384187
# [173]	valid_0's binary_logloss: 0.00383667
# [174]	valid_0's binary_logloss: 0.00383151
# [175]	valid_0's binary_logloss: 0.00382662
# [176]	valid_0's binary_logloss: 0.00382146
# [177]	valid_0's binary_logloss: 0.00381742
# [178]	valid_0's binary_logloss: 0.00381272
# [179]	valid_0's binary_logloss: 0.00380873
# [180]	valid_0's binary_logloss: 0.00380404
# [181]	valid_0's binary_logloss: 0.00380013
# [182]	valid_0's binary_logloss: 0.00379531
# [183]	valid_0's binary_logloss: 0.00379075
# [184]	valid_0's binary_logloss: 0.00378683
# [185]	valid_0's binary_logloss: 0.00378238
# [186]	valid_0's binary_logloss: 0.00377781
# [187]	valid_0's binary_logloss: 0.00377343
# [188]	valid_0's binary_logloss: 0.00376939
# [189]	valid_0's binary_logloss: 0.00376495
# [190]	valid_0's binary_logloss: 0.00376097
# [191]	valid_0's binary_logloss: 0.00375677
# [192]	valid_0's binary_logloss: 0.00375243
# [193]	valid_0's binary_logloss: 0.00374854
# [194]	valid_0's binary_logloss: 0.00374402
# [195]	valid_0's binary_logloss: 0.00373978
# [196]	valid_0's binary_logloss: 0.00373588
# [197]	valid_0's binary_logloss: 0.00373241
# [198]	valid_0's binary_logloss: 0.00372857
# [199]	valid_0's binary_logloss: 0.00372476
# [200]	valid_0's binary_logloss: 0.00372138
# [201]	valid_0's binary_logloss: 0.00371763
# [202]	valid_0's binary_logloss: 0.00371373
# Early stopping, best iteration is:
# [2]	valid_0's binary_logloss: 0.00279683
# Training Log Loss:  0.004553774242635374
# CV Log Loss:  0.002796830492891261
# LightGBM Gradient Boosting Log Loss:  0.0023977827740069976

# %% [markdown]
# ## **Precision-Recall Curve- Train**

# %%
preds, average_precision = plotResults(y_train, predictionsBasedOnKFolds.loc[:,'prediction'], True)

# %% [markdown]
# ## **Precision-Recall Curve- Test**

# %%
predictions = pd.Series(data=gbm.predict(X_test, num_iteration=gbm.best_iteration), index=X_test.index)
preds, average_precision = plotResults(y_test, predictions, True)

# %%
preds, precision = precisionAnalysis(preds, "anomalyScore", 0.75)
print("Precision at 75% recall: ", precision)
# Out:
# Precision at 75% recall:  0.0013093742681343013

# %% [markdown]
# # **Unsupervised Learning Section**

# %%
oversample_multiplier = 100

X_train_original = X_train.copy()
y_train_original = y_train.copy()
X_test_original = X_test.copy()
y_test_original = y_test.copy()

X_train_oversampled = X_train.copy()
y_train_oversampled = y_train.copy()
X_train_oversampled = X_train_oversampled.append( \
        [X_train_oversampled[y_train==1]]*oversample_multiplier, \
        ignore_index=False)
y_train_oversampled = y_train_oversampled.append( \
        [y_train_oversampled[y_train==1]]*oversample_multiplier, \
        ignore_index=False)

X_train = X_train_oversampled.copy()
y_train = y_train_oversampled.copy()

# %%
model = Sequential()
model.add(Dense(units=40, activation='linear', \
                activity_regularizer=regularizers.l1(10e-5), \
                input_dim=29,name='hidden_layer'))
model.add(Dropout(0.02))
model.add(Dense(units=29, activation='linear'))

# %%
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy'])

# %%
num_epochs = 5
batch_size = 32

history = model.fit(x=X_train, y=X_train,
                    epochs=num_epochs,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_split=0.20,
                    verbose=1)
# Out:
# Epoch 1/5
# 4846/4846 [==============================] - 13s 3ms/step - loss: 0.0766 - accuracy: 0.8650 - val_loss: 0.0304 - val_accuracy: 0.9645
# Epoch 2/5
# 4846/4846 [==============================] - 13s 3ms/step - loss: 0.0181 - accuracy: 0.9260 - val_loss: 0.0414 - val_accuracy: 0.9481
# Epoch 3/5
# 4846/4846 [==============================] - 13s 3ms/step - loss: 0.0176 - accuracy: 0.9273 - val_loss: 0.0078 - val_accuracy: 0.9801
# Epoch 4/5
# 4846/4846 [==============================] - 13s 3ms/step - loss: 0.0169 - accuracy: 0.9281 - val_loss: 0.0163 - val_accuracy: 0.9656
# Epoch 5/5
# 4846/4846 [==============================] - 13s 3ms/step - loss: 0.0175 - accuracy: 0.9266 - val_loss: 0.0149 - val_accuracy: 0.9888

# %% [markdown]
# ## **Precision-Recall Curve- Train**

# %%
predictionsTrain = model.predict(X_train_original, verbose=1)
anomalyScoresAETrain = anomalyScores(X_train_original, predictionsTrain)
preds, average_precision = plotResults(y_train_original, anomalyScoresAETrain, True)
# Out:
# 5954/5954 [==============================] - 5s 889us/step

# %% [markdown]
# ## **Precision-Recall Curve- Test**

# %%
predictions = model.predict(X_test, verbose=1)
anomalyScoresAE = anomalyScores(X_test, predictions)
preds, average_precision = plotResults(y_test, anomalyScoresAE, True)
# Out:
# 2938/2938 [==============================] - 3s 894us/step

# %%
preds, precision = precisionAnalysis(preds, "anomalyScore", 0.75)
print("Precision at 75% recall", precision)
# Out:
# Precision at 75% recall 0.42560553633217996

# %% [markdown]
# # **Semi-supervised Learning Section**

# %%
layer_name = 'hidden_layer'

intermediate_layer_model = Model(inputs=model.input, \
                                 outputs=model.get_layer(layer_name).output)
intermediate_output_train = intermediate_layer_model.predict(X_train_original)
intermediate_output_test = intermediate_layer_model.predict(X_test_original)

# %%
intermediate_output_trainDF = \
    pd.DataFrame(data=intermediate_output_train,index=X_train_original.index)
intermediate_output_testDF = \
    pd.DataFrame(data=intermediate_output_test,index=X_test_original.index)

# %%
X_train = X_train_original.merge(intermediate_output_trainDF, \
                                 left_index=True,right_index=True)
X_test = X_test_original.merge(intermediate_output_testDF, \
                               left_index=True,right_index=True)
y_train = y_train_original.copy()

# %% [markdown]
# **Printing Training Log Loss**
#
# **Printing CV Log Loss**
#
# **Printing LightGBM Gradient Boosting Log Loss**

# %%
trainingScores = []
cvScores = []
predictionsBasedOnKFolds = pd.DataFrame(data=[],index=y_train.index, \
                                        columns=['prediction'])

for train_index, cv_index in k_fold.split(np.zeros(len(X_train)), \
                                          y_train.ravel()):
    X_train_fold, X_cv_fold = X_train.iloc[train_index,:], \
        X_train.iloc[cv_index,:]
    y_train_fold, y_cv_fold = y_train.iloc[train_index], \
        y_train.iloc[cv_index]
    
    lgb_train = lgb.Dataset(X_train_fold, y_train_fold)
    lgb_eval = lgb.Dataset(X_cv_fold, y_cv_fold, reference=lgb_train)
    gbm = lgb.train(params_lightGB, lgb_train, num_boost_round=5000,
                   valid_sets=lgb_eval, early_stopping_rounds=200)
    
    loglossTraining = log_loss(y_train_fold, 
                                gbm.predict(X_train_fold, \
                                num_iteration=gbm.best_iteration))
    trainingScores.append(loglossTraining)
    
    predictionsBasedOnKFolds.loc[X_cv_fold.index,'prediction'] = \
        gbm.predict(X_cv_fold, num_iteration=gbm.best_iteration) 
    loglossCV = log_loss(y_cv_fold, \
            predictionsBasedOnKFolds.loc[X_cv_fold.index,'prediction'])
    cvScores.append(loglossCV)
    
    print('Training Log Loss: ', loglossTraining)
    print('CV Log Loss: ', loglossCV)
    
loglossLightGBMGradientBoosting = log_loss(y_train, \
                        predictionsBasedOnKFolds.loc[:,'prediction'])
print('LightGBM Gradient Boosting Log Loss: ', loglossLightGBMGradientBoosting)
# Out:
# [1]	valid_0's binary_logloss: 0.00246272
# Training until validation scores don't improve for 200 rounds.
# [2]	valid_0's binary_logloss: 0.00215653
# [3]	valid_0's binary_logloss: 0.00204708
# [4]	valid_0's binary_logloss: 0.00204625
# [5]	valid_0's binary_logloss: 0.002044
# [6]	valid_0's binary_logloss: 0.00204289
# [7]	valid_0's binary_logloss: 0.00204211
# [8]	valid_0's binary_logloss: 0.00204135
# [9]	valid_0's binary_logloss: 0.00204395
# [10]	valid_0's binary_logloss: 0.00204233
# [11]	valid_0's binary_logloss: 0.00204108
# [12]	valid_0's binary_logloss: 0.00207275
# [13]	valid_0's binary_logloss: 0.00226374
# [14]	valid_0's binary_logloss: 0.00241374
# [15]	valid_0's binary_logloss: 0.00263394
# [16]	valid_0's binary_logloss: 0.00263327
# [17]	valid_0's binary_logloss: 0.00263259
# [18]	valid_0's binary_logloss: 0.00263197
# [19]	valid_0's binary_logloss: 0.00263142
# [20]	valid_0's binary_logloss: 0.00263061
# [21]	valid_0's binary_logloss: 0.00262991
# [22]	valid_0's binary_logloss: 0.00262919
# [23]	valid_0's binary_logloss: 0.00262851
# [24]	valid_0's binary_logloss: 0.00262793
# [25]	valid_0's binary_logloss: 0.00262649
# [26]	valid_0's binary_logloss: 0.00262509
# [27]	valid_0's binary_logloss: 0.00262325
# [28]	valid_0's binary_logloss: 0.00262225
# [29]	valid_0's binary_logloss: 0.00262189
# [30]	valid_0's binary_logloss: 0.00262151
# [31]	valid_0's binary_logloss: 0.00262118
# [32]	valid_0's binary_logloss: 0.00262141
# [33]	valid_0's binary_logloss: 0.00262121
# [34]	valid_0's binary_logloss: 0.00262104
# [35]	valid_0's binary_logloss: 0.00262096
# [36]	valid_0's binary_logloss: 0.00262087
# [37]	valid_0's binary_logloss: 0.00261996
# [38]	valid_0's binary_logloss: 0.00261906
# [39]	valid_0's binary_logloss: 0.00261911
# [40]	valid_0's binary_logloss: 0.00261952
# [41]	valid_0's binary_logloss: 0.00261995
# [42]	valid_0's binary_logloss: 0.00262038
# [43]	valid_0's binary_logloss: 0.00262078
# [44]	valid_0's binary_logloss: 0.00262119
# [45]	valid_0's binary_logloss: 0.00258223
# [46]	valid_0's binary_logloss: 0.00258112
# [47]	valid_0's binary_logloss: 0.00257229
# [48]	valid_0's binary_logloss: 0.00256517
# [49]	valid_0's binary_logloss: 0.0025651
# [50]	valid_0's binary_logloss: 0.00256501
# [51]	valid_0's binary_logloss: 0.00256501
# [52]	valid_0's binary_logloss: 0.002565
# [53]	valid_0's binary_logloss: 0.00256723
# [54]	valid_0's binary_logloss: 0.00256729
# [55]	valid_0's binary_logloss: 0.0025692
# [56]	valid_0's binary_logloss: 0.00256929
# [57]	valid_0's binary_logloss: 0.00257095
# [58]	valid_0's binary_logloss: 0.00257145
# [59]	valid_0's binary_logloss: 0.002572
# [60]	valid_0's binary_logloss: 0.00257252
# [61]	valid_0's binary_logloss: 0.00257309
# [62]	valid_0's binary_logloss: 0.00257364
# [63]	valid_0's binary_logloss: 0.0025742
# [64]	valid_0's binary_logloss: 0.00257482
# [65]	valid_0's binary_logloss: 0.00257539
# [66]	valid_0's binary_logloss: 0.00257597
# [67]	valid_0's binary_logloss: 0.00257661
# [68]	valid_0's binary_logloss: 0.00257721
# [69]	valid_0's binary_logloss: 0.00257781
# [70]	valid_0's binary_logloss: 0.00257848
# [71]	valid_0's binary_logloss: 0.0025791
# [72]	valid_0's binary_logloss: 0.00257973
# [73]	valid_0's binary_logloss: 0.00258042
# [74]	valid_0's binary_logloss: 0.00258107
# [75]	valid_0's binary_logloss: 0.00258171
# [76]	valid_0's binary_logloss: 0.00258243
# [77]	valid_0's binary_logloss: 0.0025831
# [78]	valid_0's binary_logloss: 0.00258377
# [79]	valid_0's binary_logloss: 0.00258451
# [80]	valid_0's binary_logloss: 0.0025852
# [81]	valid_0's binary_logloss: 0.0025859
# [82]	valid_0's binary_logloss: 0.00258581
# [83]	valid_0's binary_logloss: 0.00258652
# [84]	valid_0's binary_logloss: 0.00258725
# [85]	valid_0's binary_logloss: 0.00258804
# [86]	valid_0's binary_logloss: 0.00258879
# [87]	valid_0's binary_logloss: 0.00258874
# [88]	valid_0's binary_logloss: 0.00258956
# [89]	valid_0's binary_logloss: 0.00259034
# [90]	valid_0's binary_logloss: 0.002591
# [91]	valid_0's binary_logloss: 0.00259104
# [92]	valid_0's binary_logloss: 0.00259184
# [93]	valid_0's binary_logloss: 0.00259251
# [94]	valid_0's binary_logloss: 0.00259338
# [95]	valid_0's binary_logloss: 0.00259341
# [96]	valid_0's binary_logloss: 0.00259427
# [97]	valid_0's binary_logloss: 0.00259501
# [98]	valid_0's binary_logloss: 0.00259507
# [99]	valid_0's binary_logloss: 0.00259593
# [100]	valid_0's binary_logloss: 0.00259683
# [101]	valid_0's binary_logloss: 0.00259679
# [102]	valid_0's binary_logloss: 0.00259767
# [103]	valid_0's binary_logloss: 0.00259857
# [104]	valid_0's binary_logloss: 0.00259946
# [105]	valid_0's binary_logloss: 0.00260032
# [106]	valid_0's binary_logloss: 0.00260038
# [107]	valid_0's binary_logloss: 0.0026014
# [108]	valid_0's binary_logloss: 0.00260241
# [109]	valid_0's binary_logloss: 0.00260271
# [110]	valid_0's binary_logloss: 0.0026036
# [111]	valid_0's binary_logloss: 0.00260389
# [112]	valid_0's binary_logloss: 0.00260421
# [113]	valid_0's binary_logloss: 0.00260522
# [114]	valid_0's binary_logloss: 0.00260613
# [115]	valid_0's binary_logloss: 0.00260717
# [116]	valid_0's binary_logloss: 0.00260749
# [117]	valid_0's binary_logloss: 0.00260854
# [118]	valid_0's binary_logloss: 0.00260887
# [119]	valid_0's binary_logloss: 0.00260978
# [120]	valid_0's binary_logloss: 0.00261014
# [121]	valid_0's binary_logloss: 0.00261118
# [122]	valid_0's binary_logloss: 0.00261223
# [123]	valid_0's binary_logloss: 0.00261259
# [124]	valid_0's binary_logloss: 0.00261352
# [125]	valid_0's binary_logloss: 0.0026139
# [126]	valid_0's binary_logloss: 0.00261495
# [127]	valid_0's binary_logloss: 0.00261602
# [128]	valid_0's binary_logloss: 0.00261629
# [129]	valid_0's binary_logloss: 0.00261735
# [130]	valid_0's binary_logloss: 0.00261775
# [131]	valid_0's binary_logloss: 0.00261882
# [132]	valid_0's binary_logloss: 0.00261923
# [133]	valid_0's binary_logloss: 0.00262029
# [134]	valid_0's binary_logloss: 0.00262138
# [135]	valid_0's binary_logloss: 0.00262178
# [136]	valid_0's binary_logloss: 0.00262221
# [137]	valid_0's binary_logloss: 0.0026233
# [138]	valid_0's binary_logloss: 0.00262493
# [139]	valid_0's binary_logloss: 0.0026259
# [140]	valid_0's binary_logloss: 0.00262633
# [141]	valid_0's binary_logloss: 0.00262797
# [142]	valid_0's binary_logloss: 0.00262841
# [143]	valid_0's binary_logloss: 0.00263006
# [144]	valid_0's binary_logloss: 0.00263114
# [145]	valid_0's binary_logloss: 0.0026316
# [146]	valid_0's binary_logloss: 0.00263184
# [147]	valid_0's binary_logloss: 0.00263207
# [148]	valid_0's binary_logloss: 0.00263232
# [149]	valid_0's binary_logloss: 0.00263257
# [150]	valid_0's binary_logloss: 0.00263283
# [151]	valid_0's binary_logloss: 0.0026331
# [152]	valid_0's binary_logloss: 0.00263337
# [153]	valid_0's binary_logloss: 0.00263365
# [154]	valid_0's binary_logloss: 0.00263394
# [155]	valid_0's binary_logloss: 0.00263423
# [156]	valid_0's binary_logloss: 0.00263453
# [157]	valid_0's binary_logloss: 0.00263484
# [158]	valid_0's binary_logloss: 0.00263515
# [159]	valid_0's binary_logloss: 0.00263547
# [160]	valid_0's binary_logloss: 0.00263579
# [161]	valid_0's binary_logloss: 0.00263612
# [162]	valid_0's binary_logloss: 0.00263646
# [163]	valid_0's binary_logloss: 0.00263681
# [164]	valid_0's binary_logloss: 0.00263716
# [165]	valid_0's binary_logloss: 0.00263751
# [166]	valid_0's binary_logloss: 0.00263788
# [167]	valid_0's binary_logloss: 0.00263825
# [168]	valid_0's binary_logloss: 0.00263862
# [169]	valid_0's binary_logloss: 0.002639
# [170]	valid_0's binary_logloss: 0.00263939
# [171]	valid_0's binary_logloss: 0.00263978
# [172]	valid_0's binary_logloss: 0.00264018
# [173]	valid_0's binary_logloss: 0.00264058
# [174]	valid_0's binary_logloss: 0.00264099
# [175]	valid_0's binary_logloss: 0.0026414
# [176]	valid_0's binary_logloss: 0.00264182
# [177]	valid_0's binary_logloss: 0.00264225
# [178]	valid_0's binary_logloss: 0.00264268
# [179]	valid_0's binary_logloss: 0.00264311
# [180]	valid_0's binary_logloss: 0.00264356
# [181]	valid_0's binary_logloss: 0.002644
# [182]	valid_0's binary_logloss: 0.00264445
# [183]	valid_0's binary_logloss: 0.00264491
# [184]	valid_0's binary_logloss: 0.00264538
# [185]	valid_0's binary_logloss: 0.00264584
# [186]	valid_0's binary_logloss: 0.00264631
# [187]	valid_0's binary_logloss: 0.00264679
# [188]	valid_0's binary_logloss: 0.00264727
# [189]	valid_0's binary_logloss: 0.00264776
# [190]	valid_0's binary_logloss: 0.00264825
# [191]	valid_0's binary_logloss: 0.00264875
# [192]	valid_0's binary_logloss: 0.00264925
# [193]	valid_0's binary_logloss: 0.00264976
# [194]	valid_0's binary_logloss: 0.00265027
# [195]	valid_0's binary_logloss: 0.00265079
# [196]	valid_0's binary_logloss: 0.00265131
# [197]	valid_0's binary_logloss: 0.00265183
# [198]	valid_0's binary_logloss: 0.00265236
# [199]	valid_0's binary_logloss: 0.00265294
# [200]	valid_0's binary_logloss: 0.00265351
# [201]	valid_0's binary_logloss: 0.00265468
# [202]	valid_0's binary_logloss: 0.00265585
# [203]	valid_0's binary_logloss: 0.00265703
# [204]	valid_0's binary_logloss: 0.00265816
# [205]	valid_0's binary_logloss: 0.00265876
# [206]	valid_0's binary_logloss: 0.00265989
# [207]	valid_0's binary_logloss: 0.00266103
# [208]	valid_0's binary_logloss: 0.00266217
# [209]	valid_0's binary_logloss: 0.00266336
# [210]	valid_0's binary_logloss: 0.00266451
# [211]	valid_0's binary_logloss: 0.00266571
# Early stopping, best iteration is:
# [11]	valid_0's binary_logloss: 0.00204108
# Training Log Loss:  0.0008656986102399165
# CV Log Loss:  0.0020410798211307206
# [1]	valid_0's binary_logloss: 0.00184498
# Training until validation scores don't improve for 200 rounds.
# [2]	valid_0's binary_logloss: 0.00178096
# [3]	valid_0's binary_logloss: 0.00125439
# [4]	valid_0's binary_logloss: 0.000735761
# [5]	valid_0's binary_logloss: 0.000385354
# [6]	valid_0's binary_logloss: 0.000383994
# [7]	valid_0's binary_logloss: 0.000382666
# [8]	valid_0's binary_logloss: 0.000381312
# [9]	valid_0's binary_logloss: 0.000379622
# [10]	valid_0's binary_logloss: 0.000378579
# [11]	valid_0's binary_logloss: 0.000377168
# [12]	valid_0's binary_logloss: 0.000375775
# [13]	valid_0's binary_logloss: 0.000374651
# [14]	valid_0's binary_logloss: 0.000372628
# [15]	valid_0's binary_logloss: 0.000371395
# [16]	valid_0's binary_logloss: 0.000370359
# [17]	valid_0's binary_logloss: 0.000368561
# [18]	valid_0's binary_logloss: 0.000366438
# [19]	valid_0's binary_logloss: 0.000364494
# [20]	valid_0's binary_logloss: 0.000362774
# [21]	valid_0's binary_logloss: 0.000361253
# [22]	valid_0's binary_logloss: 0.000359687
# [23]	valid_0's binary_logloss: 0.000358001
# [24]	valid_0's binary_logloss: 0.000356374
# [25]	valid_0's binary_logloss: 0.000355315
# [26]	valid_0's binary_logloss: 0.000353434
# [27]	valid_0's binary_logloss: 0.0003522
# [28]	valid_0's binary_logloss: 0.000350888
# [29]	valid_0's binary_logloss: 0.000349516
# [30]	valid_0's binary_logloss: 0.00034808
# [31]	valid_0's binary_logloss: 0.000347016
# [32]	valid_0's binary_logloss: 0.000345888
# [33]	valid_0's binary_logloss: 0.000343906
# [34]	valid_0's binary_logloss: 0.000342332
# [35]	valid_0's binary_logloss: 0.00034097
# [36]	valid_0's binary_logloss: 0.000339468
# [37]	valid_0's binary_logloss: 0.000338106
# [38]	valid_0's binary_logloss: 0.000336643
# [39]	valid_0's binary_logloss: 0.000335459
# [40]	valid_0's binary_logloss: 0.000334064
# [41]	valid_0's binary_logloss: 0.000332767
# [42]	valid_0's binary_logloss: 0.000331289
# [43]	valid_0's binary_logloss: 0.000329841
# [44]	valid_0's binary_logloss: 0.000328424
# [45]	valid_0's binary_logloss: 0.000327277
# [46]	valid_0's binary_logloss: 0.000325961
# [47]	valid_0's binary_logloss: 0.000324616
# [48]	valid_0's binary_logloss: 0.000323524
# [49]	valid_0's binary_logloss: 0.000322227
# [50]	valid_0's binary_logloss: 0.00032096
# [51]	valid_0's binary_logloss: 0.00031972
# [52]	valid_0's binary_logloss: 0.000318508
# [53]	valid_0's binary_logloss: 0.000317568
# [54]	valid_0's binary_logloss: 0.000316401
# [55]	valid_0's binary_logloss: 0.000315261
# [56]	valid_0's binary_logloss: 0.00031439
# [57]	valid_0's binary_logloss: 0.000313295
# [58]	valid_0's binary_logloss: 0.00031223
# [59]	valid_0's binary_logloss: 0.000311765
# [60]	valid_0's binary_logloss: 0.000311287
# [61]	valid_0's binary_logloss: 0.000310543
# [62]	valid_0's binary_logloss: 0.000310144
# [63]	valid_0's binary_logloss: 0.000309767
# [64]	valid_0's binary_logloss: 0.000309412
# [65]	valid_0's binary_logloss: 0.00030884
# [66]	valid_0's binary_logloss: 0.000308265
# [67]	valid_0's binary_logloss: 0.000307646
# [68]	valid_0's binary_logloss: 0.000307113
# [69]	valid_0's binary_logloss: 0.000306614
# [70]	valid_0's binary_logloss: 0.000306139
# [71]	valid_0's binary_logloss: 0.000305666
# [72]	valid_0's binary_logloss: 0.000304806
# [73]	valid_0's binary_logloss: 0.000304372
# [74]	valid_0's binary_logloss: 0.000304292
# [75]	valid_0's binary_logloss: 0.000303489
# [76]	valid_0's binary_logloss: 0.000302983
# [77]	valid_0's binary_logloss: 0.000302617
# [78]	valid_0's binary_logloss: 0.000302269
# [79]	valid_0's binary_logloss: 0.000301949
# [80]	valid_0's binary_logloss: 0.000301565
# [81]	valid_0's binary_logloss: 0.000301193
# [82]	valid_0's binary_logloss: 0.000300844
# [83]	valid_0's binary_logloss: 0.000300519
# [84]	valid_0's binary_logloss: 0.000300263
# [85]	valid_0's binary_logloss: 0.000300025
# [86]	valid_0's binary_logloss: 0.000299693
# [87]	valid_0's binary_logloss: 0.000299526
# [88]	valid_0's binary_logloss: 0.000299228
# [89]	valid_0's binary_logloss: 0.000298719
# [90]	valid_0's binary_logloss: 0.000298597
# [91]	valid_0's binary_logloss: 0.000298353
# [92]	valid_0's binary_logloss: 0.000297889
# [93]	valid_0's binary_logloss: 0.000297803
# [94]	valid_0's binary_logloss: 0.000297608
# [95]	valid_0's binary_logloss: 0.00029755
# [96]	valid_0's binary_logloss: 0.000297144
# [97]	valid_0's binary_logloss: 0.000296985
# [98]	valid_0's binary_logloss: 0.000296972
# [99]	valid_0's binary_logloss: 0.000296969
# [100]	valid_0's binary_logloss: 0.000296618
# [101]	valid_0's binary_logloss: 0.000296509
# [102]	valid_0's binary_logloss: 0.00029655
# [103]	valid_0's binary_logloss: 0.000296599
# [104]	valid_0's binary_logloss: 0.000296288
# [105]	valid_0's binary_logloss: 0.000296238
# [106]	valid_0's binary_logloss: 0.000296326
# [107]	valid_0's binary_logloss: 0.000296053
# [108]	valid_0's binary_logloss: 0.000296033
# [109]	valid_0's binary_logloss: 0.000296153
# [110]	valid_0's binary_logloss: 0.000296284
# [111]	valid_0's binary_logloss: 0.000296058
# [112]	valid_0's binary_logloss: 0.000296085
# [113]	valid_0's binary_logloss: 0.000296247
# [114]	valid_0's binary_logloss: 0.000296055
# [115]	valid_0's binary_logloss: 0.000296236
# [116]	valid_0's binary_logloss: 0.000296424
# [117]	valid_0's binary_logloss: 0.000296518
# [118]	valid_0's binary_logloss: 0.000296369
# [119]	valid_0's binary_logloss: 0.000296588
# [120]	valid_0's binary_logloss: 0.000296458
# [121]	valid_0's binary_logloss: 0.000296691
# [122]	valid_0's binary_logloss: 0.000296935
# [123]	valid_0's binary_logloss: 0.000296854
# [124]	valid_0's binary_logloss: 0.000297017
# [125]	valid_0's binary_logloss: 0.000296966
# [126]	valid_0's binary_logloss: 0.000297238
# [127]	valid_0's binary_logloss: 0.000297522
# [128]	valid_0's binary_logloss: 0.000297813
# [129]	valid_0's binary_logloss: 0.000297787
# [130]	valid_0's binary_logloss: 0.000298092
# [131]	valid_0's binary_logloss: 0.000298085
# [132]	valid_0's binary_logloss: 0.000298415
# [133]	valid_0's binary_logloss: 0.000298659
# [134]	valid_0's binary_logloss: 0.000298686
# [135]	valid_0's binary_logloss: 0.00029903
# [136]	valid_0's binary_logloss: 0.000299391
# [137]	valid_0's binary_logloss: 0.000299433
# [138]	valid_0's binary_logloss: 0.000299799
# [139]	valid_0's binary_logloss: 0.00030018
# [140]	valid_0's binary_logloss: 0.000300254
# [141]	valid_0's binary_logloss: 0.00030063
# [142]	valid_0's binary_logloss: 0.000300711
# [143]	valid_0's binary_logloss: 0.000301098
# [144]	valid_0's binary_logloss: 0.000301488
# [145]	valid_0's binary_logloss: 0.000301897
# [146]	valid_0's binary_logloss: 0.000302015
# [147]	valid_0's binary_logloss: 0.000302429
# [148]	valid_0's binary_logloss: 0.000302553
# [149]	valid_0's binary_logloss: 0.000302987
# [150]	valid_0's binary_logloss: 0.000303126
# [151]	valid_0's binary_logloss: 0.000303565
# [152]	valid_0's binary_logloss: 0.000304018
# [153]	valid_0's binary_logloss: 0.000304183
# [154]	valid_0's binary_logloss: 0.000304647
# [155]	valid_0's binary_logloss: 0.00030511
# [156]	valid_0's binary_logloss: 0.000305288
# [157]	valid_0's binary_logloss: 0.00030577
# [158]	valid_0's binary_logloss: 0.000305967
# [159]	valid_0's binary_logloss: 0.000306459
# [160]	valid_0's binary_logloss: 0.000306951
# [161]	valid_0's binary_logloss: 0.000307159
# [162]	valid_0's binary_logloss: 0.000307671
# [163]	valid_0's binary_logloss: 0.000308188
# [164]	valid_0's binary_logloss: 0.000308423
# [165]	valid_0's binary_logloss: 0.000308951
# [166]	valid_0's binary_logloss: 0.000309193
# [167]	valid_0's binary_logloss: 0.00030973
# [168]	valid_0's binary_logloss: 0.000310273
# [169]	valid_0's binary_logloss: 0.000310823
# [170]	valid_0's binary_logloss: 0.00031109
# [171]	valid_0's binary_logloss: 0.000311648
# [172]	valid_0's binary_logloss: 0.000312213
# [173]	valid_0's binary_logloss: 0.000312491
# [174]	valid_0's binary_logloss: 0.000312577
# [175]	valid_0's binary_logloss: 0.000312869
# [176]	valid_0's binary_logloss: 0.000312968
# [177]	valid_0's binary_logloss: 0.000313082
# [178]	valid_0's binary_logloss: 0.000312239
# [179]	valid_0's binary_logloss: 0.000311397
# [180]	valid_0's binary_logloss: 0.000310573
# [181]	valid_0's binary_logloss: 0.000309746
# [182]	valid_0's binary_logloss: 0.000308928
# [183]	valid_0's binary_logloss: 0.000308121
# [184]	valid_0's binary_logloss: 0.000307317
# [185]	valid_0's binary_logloss: 0.000306524
# [186]	valid_0's binary_logloss: 0.000305734
# [187]	valid_0's binary_logloss: 0.000304948
# [188]	valid_0's binary_logloss: 0.000304172
# [189]	valid_0's binary_logloss: 0.000303405
# [190]	valid_0's binary_logloss: 0.000302642
# [191]	valid_0's binary_logloss: 0.000301886
# [192]	valid_0's binary_logloss: 0.000301139
# [193]	valid_0's binary_logloss: 0.000300396
# [194]	valid_0's binary_logloss: 0.000299639
# [195]	valid_0's binary_logloss: 0.000298904
# [196]	valid_0's binary_logloss: 0.000298185
# [197]	valid_0's binary_logloss: 0.000297447
# [198]	valid_0's binary_logloss: 0.000296735
# [199]	valid_0's binary_logloss: 0.000296032
# [200]	valid_0's binary_logloss: 0.000295333
# [201]	valid_0's binary_logloss: 0.000294635
# [202]	valid_0's binary_logloss: 0.000293952
# [203]	valid_0's binary_logloss: 0.000293251
# [204]	valid_0's binary_logloss: 0.000292576
# [205]	valid_0's binary_logloss: 0.000291902
# [206]	valid_0's binary_logloss: 0.000291242
# [207]	valid_0's binary_logloss: 0.000290565
# [208]	valid_0's binary_logloss: 0.000289914
# [209]	valid_0's binary_logloss: 0.000289268
# [210]	valid_0's binary_logloss: 0.000288631
# [211]	valid_0's binary_logloss: 0.000287992
# [212]	valid_0's binary_logloss: 0.000287367
# [213]	valid_0's binary_logloss: 0.000286723
# [214]	valid_0's binary_logloss: 0.000286101
# [215]	valid_0's binary_logloss: 0.000285488
# [216]	valid_0's binary_logloss: 0.000284885
# [217]	valid_0's binary_logloss: 0.000284284
# [218]	valid_0's binary_logloss: 0.00028366
# [219]	valid_0's binary_logloss: 0.00028307
# [220]	valid_0's binary_logloss: 0.000282457
# [221]	valid_0's binary_logloss: 0.000281858
# [222]	valid_0's binary_logloss: 0.000281284
# [223]	valid_0's binary_logloss: 0.000280692
# [224]	valid_0's binary_logloss: 0.00028013
# [225]	valid_0's binary_logloss: 0.000279549
# [226]	valid_0's binary_logloss: 0.000278995
# [227]	valid_0's binary_logloss: 0.00027842
# [228]	valid_0's binary_logloss: 0.000277876
# [229]	valid_0's binary_logloss: 0.000277316
# [230]	valid_0's binary_logloss: 0.000276785
# [231]	valid_0's binary_logloss: 0.000276231
# [232]	valid_0's binary_logloss: 0.000275707
# [233]	valid_0's binary_logloss: 0.000275167
# [234]	valid_0's binary_logloss: 0.000274653
# [235]	valid_0's binary_logloss: 0.000274144
# [236]	valid_0's binary_logloss: 0.000273619
# [237]	valid_0's binary_logloss: 0.000273122
# [238]	valid_0's binary_logloss: 0.000272603
# [239]	valid_0's binary_logloss: 0.000272093
# [240]	valid_0's binary_logloss: 0.00027161
# [241]	valid_0's binary_logloss: 0.00027111
# [242]	valid_0's binary_logloss: 0.000270635
# [243]	valid_0's binary_logloss: 0.000271025
# [244]	valid_0's binary_logloss: 0.00027053
# [245]	valid_0's binary_logloss: 0.000270064
# [246]	valid_0's binary_logloss: 0.000270458
# [247]	valid_0's binary_logloss: 0.000269974
# [248]	valid_0's binary_logloss: 0.000269517
# [249]	valid_0's binary_logloss: 0.000269916
# [250]	valid_0's binary_logloss: 0.000269446
# [251]	valid_0's binary_logloss: 0.000269849
# [252]	valid_0's binary_logloss: 0.000269401
# [253]	valid_0's binary_logloss: 0.000268962
# [254]	valid_0's binary_logloss: 0.000269366
# [255]	valid_0's binary_logloss: 0.000268906
# [256]	valid_0's binary_logloss: 0.000268454
# [257]	valid_0's binary_logloss: 0.000268847
# [258]	valid_0's binary_logloss: 0.000269249
# [259]	valid_0's binary_logloss: 0.000268803
# [260]	valid_0's binary_logloss: 0.000269218
# [261]	valid_0's binary_logloss: 0.000268794
# [262]	valid_0's binary_logloss: 0.000268377
# [263]	valid_0's binary_logloss: 0.000268793
# [264]	valid_0's binary_logloss: 0.000268361
# [265]	valid_0's binary_logloss: 0.000268969
# [266]	valid_0's binary_logloss: 0.000268541
# [267]	valid_0's binary_logloss: 0.000268135
# [268]	valid_0's binary_logloss: 0.000268743
# [269]	valid_0's binary_logloss: 0.000268322
# [270]	valid_0's binary_logloss: 0.000268923
# [271]	valid_0's binary_logloss: 0.000269538
# [272]	valid_0's binary_logloss: 0.000269135
# [273]	valid_0's binary_logloss: 0.000268721
# [274]	valid_0's binary_logloss: 0.000269327
# [275]	valid_0's binary_logloss: 0.000269946
# [276]	valid_0's binary_logloss: 0.000269553
# [277]	valid_0's binary_logloss: 0.000269145
# [278]	valid_0's binary_logloss: 0.000269755
# [279]	valid_0's binary_logloss: 0.000269355
# [280]	valid_0's binary_logloss: 0.000269976
# [281]	valid_0's binary_logloss: 0.000269588
# [282]	valid_0's binary_logloss: 0.000269205
# [283]	valid_0's binary_logloss: 0.000268852
# [284]	valid_0's binary_logloss: 0.000269464
# [285]	valid_0's binary_logloss: 0.000269108
# [286]	valid_0's binary_logloss: 0.000268721
# [287]	valid_0's binary_logloss: 0.000268366
# [288]	valid_0's binary_logloss: 0.000268024
# [289]	valid_0's binary_logloss: 0.000267672
# [290]	valid_0's binary_logloss: 0.000267318
# [291]	valid_0's binary_logloss: 0.000266977
# [292]	valid_0's binary_logloss: 0.00026665
# [293]	valid_0's binary_logloss: 0.00026629
# [294]	valid_0's binary_logloss: 0.000265963
# [295]	valid_0's binary_logloss: 0.000265648
# [296]	valid_0's binary_logloss: 0.000265329
# [297]	valid_0's binary_logloss: 0.000264984
# [298]	valid_0's binary_logloss: 0.000264673
# [299]	valid_0's binary_logloss: 0.000264374
# [300]	valid_0's binary_logloss: 0.000264053
# [301]	valid_0's binary_logloss: 0.00026376
# [302]	valid_0's binary_logloss: 0.000263463
# [303]	valid_0's binary_logloss: 0.000263166
# [304]	valid_0's binary_logloss: 0.000262862
# [305]	valid_0's binary_logloss: 0.000262585
# [306]	valid_0's binary_logloss: 0.000262304
# [307]	valid_0's binary_logloss: 0.000262002
# [308]	valid_0's binary_logloss: 0.000261736
# [309]	valid_0's binary_logloss: 0.000261466
# [310]	valid_0's binary_logloss: 0.0002612
# [311]	valid_0's binary_logloss: 0.000260919
# [312]	valid_0's binary_logloss: 0.00026067
# [313]	valid_0's binary_logloss: 0.000260415
# [314]	valid_0's binary_logloss: 0.000260159
# [315]	valid_0's binary_logloss: 0.000259895
# [316]	valid_0's binary_logloss: 0.000259657
# [317]	valid_0's binary_logloss: 0.000259419
# [318]	valid_0's binary_logloss: 0.000259155
# [319]	valid_0's binary_logloss: 0.000259731
# [320]	valid_0's binary_logloss: 0.000259504
# [321]	valid_0's binary_logloss: 0.000259555
# [322]	valid_0's binary_logloss: 0.000259322
# [323]	valid_0's binary_logloss: 0.000259084
# [324]	valid_0's binary_logloss: 0.000258842
# [325]	valid_0's binary_logloss: 0.000258891
# [326]	valid_0's binary_logloss: 0.000258661
# [327]	valid_0's binary_logloss: 0.000258435
# [328]	valid_0's binary_logloss: 0.000259006
# [329]	valid_0's binary_logloss: 0.000258782
# [330]	valid_0's binary_logloss: 0.00025854
# [331]	valid_0's binary_logloss: 0.000258323
# [332]	valid_0's binary_logloss: 0.000258121
# [333]	valid_0's binary_logloss: 0.000257932
# [334]	valid_0's binary_logloss: 0.000257926
# [335]	valid_0's binary_logloss: 0.000257932
# [336]	valid_0's binary_logloss: 0.0002577
# [337]	valid_0's binary_logloss: 0.000257501
# [338]	valid_0's binary_logloss: 0.000257306
# [339]	valid_0's binary_logloss: 0.000257113
# [340]	valid_0's binary_logloss: 0.000257672
# [341]	valid_0's binary_logloss: 0.000257459
# [342]	valid_0's binary_logloss: 0.000257272
# [343]	valid_0's binary_logloss: 0.000257108
# [344]	valid_0's binary_logloss: 0.00025718
# [345]	valid_0's binary_logloss: 0.000257001
# [346]	valid_0's binary_logloss: 0.000256797
# [347]	valid_0's binary_logloss: 0.000257351
# [348]	valid_0's binary_logloss: 0.00025718
# [349]	valid_0's binary_logloss: 0.000257011
# [350]	valid_0's binary_logloss: 0.000256836
# [351]	valid_0's binary_logloss: 0.000257388
# [352]	valid_0's binary_logloss: 0.000257225
# [353]	valid_0's binary_logloss: 0.000257066
# [354]	valid_0's binary_logloss: 0.000256916
# [355]	valid_0's binary_logloss: 0.000257007
# [356]	valid_0's binary_logloss: 0.000256825
# [357]	valid_0's binary_logloss: 0.000256683
# [358]	valid_0's binary_logloss: 0.000256539
# [359]	valid_0's binary_logloss: 0.000257071
# [360]	valid_0's binary_logloss: 0.000257616
# [361]	valid_0's binary_logloss: 0.000258155
# [362]	valid_0's binary_logloss: 0.000258707
# [363]	valid_0's binary_logloss: 0.000259251
# [364]	valid_0's binary_logloss: 0.000259268
# [365]	valid_0's binary_logloss: 0.000259362
# [366]	valid_0's binary_logloss: 0.000259909
# [367]	valid_0's binary_logloss: 0.000260468
# [368]	valid_0's binary_logloss: 0.000261019
# [369]	valid_0's binary_logloss: 0.00026097
# [370]	valid_0's binary_logloss: 0.000261016
# [371]	valid_0's binary_logloss: 0.000260975
# [372]	valid_0's binary_logloss: 0.000261028
# [373]	valid_0's binary_logloss: 0.000260994
# [374]	valid_0's binary_logloss: 0.000261054
# [375]	valid_0's binary_logloss: 0.000261435
# [376]	valid_0's binary_logloss: 0.000261412
# [377]	valid_0's binary_logloss: 0.000261483
# [378]	valid_0's binary_logloss: 0.000261652
# [379]	valid_0's binary_logloss: 0.00026164
# [380]	valid_0's binary_logloss: 0.000261815
# [381]	valid_0's binary_logloss: 0.0002619
# [382]	valid_0's binary_logloss: 0.000262039
# [383]	valid_0's binary_logloss: 0.000262441
# [384]	valid_0's binary_logloss: 0.000262447
# [385]	valid_0's binary_logloss: 0.00026242
# [386]	valid_0's binary_logloss: 0.000262573
# [387]	valid_0's binary_logloss: 0.000262679
# [388]	valid_0's binary_logloss: 0.000262663
# [389]	valid_0's binary_logloss: 0.000263083
# [390]	valid_0's binary_logloss: 0.000263249
# [391]	valid_0's binary_logloss: 0.000263244
# [392]	valid_0's binary_logloss: 0.000263558
# [393]	valid_0's binary_logloss: 0.000263594
# [394]	valid_0's binary_logloss: 0.000263915
# [395]	valid_0's binary_logloss: 0.000264158
# [396]	valid_0's binary_logloss: 0.000264168
# [397]	valid_0's binary_logloss: 0.000264416
# [398]	valid_0's binary_logloss: 0.000264748
# [399]	valid_0's binary_logloss: 0.000265
# [400]	valid_0's binary_logloss: 0.000265148
# [401]	valid_0's binary_logloss: 0.000265576
# [402]	valid_0's binary_logloss: 0.000265919
# [403]	valid_0's binary_logloss: 0.000266181
# [404]	valid_0's binary_logloss: 0.000266214
# [405]	valid_0's binary_logloss: 0.000266649
# [406]	valid_0's binary_logloss: 0.000267003
# [407]	valid_0's binary_logloss: 0.000267273
# [408]	valid_0's binary_logloss: 0.000267711
# [409]	valid_0's binary_logloss: 0.000267758
# [410]	valid_0's binary_logloss: 0.000268122
# [411]	valid_0's binary_logloss: 0.000268402
# [412]	valid_0's binary_logloss: 0.000268846
# [413]	valid_0's binary_logloss: 0.000269218
# [414]	valid_0's binary_logloss: 0.000269663
# [415]	valid_0's binary_logloss: 0.000269951
# [416]	valid_0's binary_logloss: 0.000270017
# [417]	valid_0's binary_logloss: 0.000270468
# [418]	valid_0's binary_logloss: 0.000270852
# [419]	valid_0's binary_logloss: 0.000271148
# [420]	valid_0's binary_logloss: 0.000271602
# [421]	valid_0's binary_logloss: 0.000271994
# [422]	valid_0's binary_logloss: 0.000272296
# [423]	valid_0's binary_logloss: 0.000272287
# [424]	valid_0's binary_logloss: 0.000272374
# [425]	valid_0's binary_logloss: 0.000272776
# [426]	valid_0's binary_logloss: 0.000272775
# [427]	valid_0's binary_logloss: 0.000273089
# [428]	valid_0's binary_logloss: 0.000273558
# [429]	valid_0's binary_logloss: 0.000273969
# [430]	valid_0's binary_logloss: 0.000274199
# [431]	valid_0's binary_logloss: 0.000274521
# [432]	valid_0's binary_logloss: 0.000274538
# [433]	valid_0's binary_logloss: 0.000274958
# [434]	valid_0's binary_logloss: 0.000274981
# [435]	valid_0's binary_logloss: 0.000275312
# [436]	valid_0's binary_logloss: 0.000275557
# [437]	valid_0's binary_logloss: 0.000275587
# [438]	valid_0's binary_logloss: 0.000276019
# [439]	valid_0's binary_logloss: 0.000276358
# [440]	valid_0's binary_logloss: 0.000276398
# [441]	valid_0's binary_logloss: 0.000276656
# [442]	valid_0's binary_logloss: 0.000277151
# [443]	valid_0's binary_logloss: 0.000277594
# [444]	valid_0's binary_logloss: 0.000277943
# [445]	valid_0's binary_logloss: 0.000277994
# [446]	valid_0's binary_logloss: 0.000278134
# [447]	valid_0's binary_logloss: 0.000278192
# [448]	valid_0's binary_logloss: 0.000278646
# [449]	valid_0's binary_logloss: 0.000279005
# [450]	valid_0's binary_logloss: 0.00027907
# [451]	valid_0's binary_logloss: 0.000279433
# [452]	valid_0's binary_logloss: 0.000279717
# [453]	valid_0's binary_logloss: 0.000280232
# [454]	valid_0's binary_logloss: 0.000280699
# [455]	valid_0's binary_logloss: 0.000281069
# [456]	valid_0's binary_logloss: 0.000281149
# [457]	valid_0's binary_logloss: 0.000281623
# [458]	valid_0's binary_logloss: 0.000281709
# [459]	valid_0's binary_logloss: 0.000282009
# [460]	valid_0's binary_logloss: 0.000282388
# [461]	valid_0's binary_logloss: 0.000282481
# [462]	valid_0's binary_logloss: 0.000282965
# [463]	valid_0's binary_logloss: 0.000283062
# [464]	valid_0's binary_logloss: 0.000283373
# [465]	valid_0's binary_logloss: 0.000283762
# [466]	valid_0's binary_logloss: 0.000283867
# [467]	valid_0's binary_logloss: 0.000284361
# [468]	valid_0's binary_logloss: 0.000284755
# [469]	valid_0's binary_logloss: 0.000284867
# [470]	valid_0's binary_logloss: 0.000285191
# [471]	valid_0's binary_logloss: 0.000285735
# [472]	valid_0's binary_logloss: 0.000286239
# [473]	valid_0's binary_logloss: 0.000286641
# [474]	valid_0's binary_logloss: 0.000287171
# [475]	valid_0's binary_logloss: 0.000287296
# [476]	valid_0's binary_logloss: 0.000287499
# [477]	valid_0's binary_logloss: 0.000288012
# [478]	valid_0's binary_logloss: 0.000288142
# [479]	valid_0's binary_logloss: 0.000288555
# [480]	valid_0's binary_logloss: 0.000289097
# [481]	valid_0's binary_logloss: 0.000289235
# [482]	valid_0's binary_logloss: 0.000289585
# [483]	valid_0's binary_logloss: 0.000290005
# [484]	valid_0's binary_logloss: 0.000290568
# [485]	valid_0's binary_logloss: 0.000291116
# [486]	valid_0's binary_logloss: 0.000291336
# [487]	valid_0's binary_logloss: 0.000292056
# [488]	valid_0's binary_logloss: 0.000292207
# [489]	valid_0's binary_logloss: 0.000292634
# [490]	valid_0's binary_logloss: 0.00029319
# [491]	valid_0's binary_logloss: 0.000293551
# [492]	valid_0's binary_logloss: 0.000293708
# [493]	valid_0's binary_logloss: 0.000294315
# [494]	valid_0's binary_logloss: 0.000295045
# [495]	valid_0's binary_logloss: 0.000295606
# [496]	valid_0's binary_logloss: 0.000295769
# [497]	valid_0's binary_logloss: 0.000296371
# [498]	valid_0's binary_logloss: 0.000296813
# [499]	valid_0's binary_logloss: 0.000297417
# [500]	valid_0's binary_logloss: 0.000297986
# [501]	valid_0's binary_logloss: 0.000298362
# [502]	valid_0's binary_logloss: 0.000298971
# [503]	valid_0's binary_logloss: 0.000299542
# [504]	valid_0's binary_logloss: 0.000299719
# [505]	valid_0's binary_logloss: 0.000300333
# [506]	valid_0's binary_logloss: 0.00030108
# [507]	valid_0's binary_logloss: 0.000301386
# [508]	valid_0's binary_logloss: 0.000302004
# [509]	valid_0's binary_logloss: 0.000302584
# [510]	valid_0's binary_logloss: 0.000303205
# [511]	valid_0's binary_logloss: 0.000303959
# [512]	valid_0's binary_logloss: 0.000304542
# [513]	valid_0's binary_logloss: 0.000304733
# [514]	valid_0's binary_logloss: 0.00030536
# [515]	valid_0's binary_logloss: 0.000305678
# [516]	valid_0's binary_logloss: 0.000306308
# [517]	valid_0's binary_logloss: 0.000306898
# [518]	valid_0's binary_logloss: 0.000307661
# [519]	valid_0's binary_logloss: 0.000307861
# [520]	valid_0's binary_logloss: 0.000308498
# [521]	valid_0's binary_logloss: 0.00030934
# [522]	valid_0's binary_logloss: 0.000309935
# [523]	valid_0's binary_logloss: 0.000310789
# [524]	valid_0's binary_logloss: 0.000311391
# [525]	valid_0's binary_logloss: 0.000312248
# [526]	valid_0's binary_logloss: 0.000312699
# [527]	valid_0's binary_logloss: 0.000313559
# [528]	valid_0's binary_logloss: 0.000314162
# [529]	valid_0's binary_logloss: 0.000314763
# [530]	valid_0's binary_logloss: 0.000315628
# [531]	valid_0's binary_logloss: 0.000316228
# [532]	valid_0's binary_logloss: 0.000317095
# [533]	valid_0's binary_logloss: 0.000317549
# [534]	valid_0's binary_logloss: 0.000318149
# [535]	valid_0's binary_logloss: 0.00031902
# [536]	valid_0's binary_logloss: 0.000319619
# [537]	valid_0's binary_logloss: 0.000320493
# [538]	valid_0's binary_logloss: 0.000320948
# [539]	valid_0's binary_logloss: 0.000321546
# [540]	valid_0's binary_logloss: 0.000322424
# [541]	valid_0's binary_logloss: 0.00032302
# [542]	valid_0's binary_logloss: 0.000323901
# [543]	valid_0's binary_logloss: 0.000324358
# [544]	valid_0's binary_logloss: 0.000324953
# [545]	valid_0's binary_logloss: 0.000325837
# [546]	valid_0's binary_logloss: 0.000326432
# [547]	valid_0's binary_logloss: 0.000327319
# [548]	valid_0's binary_logloss: 0.000327912
# [549]	valid_0's binary_logloss: 0.000328798
# [550]	valid_0's binary_logloss: 0.000329205
# [551]	valid_0's binary_logloss: 0.00032961
# [552]	valid_0's binary_logloss: 0.000330503
# [553]	valid_0's binary_logloss: 0.000331097
# [554]	valid_0's binary_logloss: 0.000331503
# [555]	valid_0's binary_logloss: 0.000332399
# [556]	valid_0's binary_logloss: 0.000332992
# [557]	valid_0's binary_logloss: 0.000333489
# [558]	valid_0's binary_logloss: 0.000334388
# Early stopping, best iteration is:
# [358]	valid_0's binary_logloss: 0.000256539
# Training Log Loss:  1.8175397510846066e-05
# CV Log Loss:  0.00025653862714445876
# [1]	valid_0's binary_logloss: 0.00473293
# Training until validation scores don't improve for 200 rounds.
# [2]	valid_0's binary_logloss: 0.00397452
# [3]	valid_0's binary_logloss: 0.00387689
# [4]	valid_0's binary_logloss: 0.00345849
# [5]	valid_0's binary_logloss: 0.0034553
# [6]	valid_0's binary_logloss: 0.00345218
# [7]	valid_0's binary_logloss: 0.00344882
# [8]	valid_0's binary_logloss: 0.00344559
# [9]	valid_0's binary_logloss: 0.00344231
# [10]	valid_0's binary_logloss: 0.00343907
# [11]	valid_0's binary_logloss: 0.00343596
# [12]	valid_0's binary_logloss: 0.0034328
# [13]	valid_0's binary_logloss: 0.00343189
# [14]	valid_0's binary_logloss: 0.00343235
# [15]	valid_0's binary_logloss: 0.00342942
# [16]	valid_0's binary_logloss: 0.00342655
# [17]	valid_0's binary_logloss: 0.0034235
# [18]	valid_0's binary_logloss: 0.00342053
# [19]	valid_0's binary_logloss: 0.0034176
# [20]	valid_0's binary_logloss: 0.00341456
# [21]	valid_0's binary_logloss: 0.00341327
# [22]	valid_0's binary_logloss: 0.00341661
# [23]	valid_0's binary_logloss: 0.0034138
# [24]	valid_0's binary_logloss: 0.00341089
# [25]	valid_0's binary_logloss: 0.00340796
# [26]	valid_0's binary_logloss: 0.00340481
# [27]	valid_0's binary_logloss: 0.00339795
# [28]	valid_0's binary_logloss: 0.00339378
# [29]	valid_0's binary_logloss: 0.00339065
# [30]	valid_0's binary_logloss: 0.00338778
# [31]	valid_0's binary_logloss: 0.00338302
# [32]	valid_0's binary_logloss: 0.00337828
# [33]	valid_0's binary_logloss: 0.00337357
# [34]	valid_0's binary_logloss: 0.00336896
# [35]	valid_0's binary_logloss: 0.00336439
# [36]	valid_0's binary_logloss: 0.00335996
# [37]	valid_0's binary_logloss: 0.00335709
# [38]	valid_0's binary_logloss: 0.00335274
# [39]	valid_0's binary_logloss: 0.00334995
# [40]	valid_0's binary_logloss: 0.00334575
# [41]	valid_0's binary_logloss: 0.00334297
# [42]	valid_0's binary_logloss: 0.00333893
# [43]	valid_0's binary_logloss: 0.0033362
# [44]	valid_0's binary_logloss: 0.00333351
# [45]	valid_0's binary_logloss: 0.00332968
# [46]	valid_0's binary_logloss: 0.00332704
# [47]	valid_0's binary_logloss: 0.00332509
# [48]	valid_0's binary_logloss: 0.00332314
# [49]	valid_0's binary_logloss: 0.00332214
# [50]	valid_0's binary_logloss: 0.00332023
# [51]	valid_0's binary_logloss: 0.00331763
# [52]	valid_0's binary_logloss: 0.00331573
# [53]	valid_0's binary_logloss: 0.00331384
# [54]	valid_0's binary_logloss: 0.00331289
# [55]	valid_0's binary_logloss: 0.00331195
# [56]	valid_0's binary_logloss: 0.00331008
# [57]	valid_0's binary_logloss: 0.00330823
# [58]	valid_0's binary_logloss: 0.0033073
# [59]	valid_0's binary_logloss: 0.00330546
# [60]	valid_0's binary_logloss: 0.00330431
# [61]	valid_0's binary_logloss: 0.00330308
# [62]	valid_0's binary_logloss: 0.00330185
# [63]	valid_0's binary_logloss: 0.0033007
# [64]	valid_0's binary_logloss: 0.0032995
# [65]	valid_0's binary_logloss: 0.00329662
# [66]	valid_0's binary_logloss: 0.00329384
# [67]	valid_0's binary_logloss: 0.003291
# [68]	valid_0's binary_logloss: 0.0032882
# [69]	valid_0's binary_logloss: 0.00328541
# [70]	valid_0's binary_logloss: 0.00328273
# [71]	valid_0's binary_logloss: 0.00327998
# [72]	valid_0's binary_logloss: 0.00327726
# [73]	valid_0's binary_logloss: 0.00327463
# [74]	valid_0's binary_logloss: 0.00327197
# [75]	valid_0's binary_logloss: 0.00326932
# [76]	valid_0's binary_logloss: 0.00326669
# [77]	valid_0's binary_logloss: 0.00326415
# [78]	valid_0's binary_logloss: 0.00326156
# [79]	valid_0's binary_logloss: 0.00325899
# [80]	valid_0's binary_logloss: 0.00325651
# [81]	valid_0's binary_logloss: 0.00325399
# [82]	valid_0's binary_logloss: 0.0032515
# [83]	valid_0's binary_logloss: 0.00324907
# [84]	valid_0's binary_logloss: 0.00324661
# [85]	valid_0's binary_logloss: 0.00324416
# [86]	valid_0's binary_logloss: 0.00324174
# [87]	valid_0's binary_logloss: 0.0032394
# [88]	valid_0's binary_logloss: 0.00323701
# [89]	valid_0's binary_logloss: 0.00323465
# [90]	valid_0's binary_logloss: 0.00323235
# [91]	valid_0's binary_logloss: 0.00323001
# [92]	valid_0's binary_logloss: 0.0032277
# [93]	valid_0's binary_logloss: 0.00322546
# [94]	valid_0's binary_logloss: 0.00322317
# [95]	valid_0's binary_logloss: 0.00322091
# [96]	valid_0's binary_logloss: 0.00321866
# [97]	valid_0's binary_logloss: 0.00321642
# [98]	valid_0's binary_logloss: 0.00321426
# [99]	valid_0's binary_logloss: 0.00321207
# [100]	valid_0's binary_logloss: 0.00320988
# [101]	valid_0's binary_logloss: 0.00320777
# [102]	valid_0's binary_logloss: 0.00320562
# [103]	valid_0's binary_logloss: 0.00320353
# [104]	valid_0's binary_logloss: 0.00320141
# [105]	valid_0's binary_logloss: 0.0031993
# [106]	valid_0's binary_logloss: 0.00319764
# [107]	valid_0's binary_logloss: 0.00319604
# [108]	valid_0's binary_logloss: 0.0031944
# [109]	valid_0's binary_logloss: 0.00319277
# [110]	valid_0's binary_logloss: 0.00319116
# [111]	valid_0's binary_logloss: 0.00318954
# [112]	valid_0's binary_logloss: 0.00318798
# [113]	valid_0's binary_logloss: 0.00318639
# [114]	valid_0's binary_logloss: 0.00318481
# [115]	valid_0's binary_logloss: 0.00318288
# [116]	valid_0's binary_logloss: 0.00318131
# [117]	valid_0's binary_logloss: 0.00317975
# [118]	valid_0's binary_logloss: 0.00317821
# [119]	valid_0's binary_logloss: 0.00317667
# [120]	valid_0's binary_logloss: 0.00317519
# [121]	valid_0's binary_logloss: 0.00317367
# [122]	valid_0's binary_logloss: 0.00317178
# [123]	valid_0's binary_logloss: 0.0031702
# [124]	valid_0's binary_logloss: 0.00316859
# [125]	valid_0's binary_logloss: 0.00316699
# [126]	valid_0's binary_logloss: 0.00316543
# [127]	valid_0's binary_logloss: 0.00316385
# [128]	valid_0's binary_logloss: 0.00316228
# [129]	valid_0's binary_logloss: 0.00316072
# [130]	valid_0's binary_logloss: 0.00315917
# [131]	valid_0's binary_logloss: 0.00315763
# [132]	valid_0's binary_logloss: 0.00315609
# [133]	valid_0's binary_logloss: 0.00315457
# [134]	valid_0's binary_logloss: 0.00315305
# [135]	valid_0's binary_logloss: 0.00315154
# [136]	valid_0's binary_logloss: 0.00315005
# [137]	valid_0's binary_logloss: 0.00314859
# [138]	valid_0's binary_logloss: 0.0031471
# [139]	valid_0's binary_logloss: 0.00314563
# [140]	valid_0's binary_logloss: 0.00314416
# [141]	valid_0's binary_logloss: 0.0031427
# [142]	valid_0's binary_logloss: 0.00314125
# [143]	valid_0's binary_logloss: 0.0031398
# [144]	valid_0's binary_logloss: 0.00313866
# [145]	valid_0's binary_logloss: 0.00313724
# [146]	valid_0's binary_logloss: 0.00313611
# [147]	valid_0's binary_logloss: 0.00313472
# [148]	valid_0's binary_logloss: 0.00313361
# [149]	valid_0's binary_logloss: 0.00313221
# [150]	valid_0's binary_logloss: 0.00313173
# [151]	valid_0's binary_logloss: 0.00313035
# [152]	valid_0's binary_logloss: 0.00313002
# [153]	valid_0's binary_logloss: 0.0031297
# [154]	valid_0's binary_logloss: 0.00312806
# [155]	valid_0's binary_logloss: 0.00312659
# [156]	valid_0's binary_logloss: 0.00312498
# [157]	valid_0's binary_logloss: 0.00312338
# [158]	valid_0's binary_logloss: 0.00312179
# [159]	valid_0's binary_logloss: 0.00312021
# [160]	valid_0's binary_logloss: 0.0031188
# [161]	valid_0's binary_logloss: 0.00311724
# [162]	valid_0's binary_logloss: 0.0031157
# [163]	valid_0's binary_logloss: 0.00311416
# [164]	valid_0's binary_logloss: 0.00311264
# [165]	valid_0's binary_logloss: 0.00311113
# [166]	valid_0's binary_logloss: 0.00310977
# [167]	valid_0's binary_logloss: 0.00310828
# [168]	valid_0's binary_logloss: 0.0031068
# [169]	valid_0's binary_logloss: 0.00310533
# [170]	valid_0's binary_logloss: 0.0031039
# [171]	valid_0's binary_logloss: 0.00310262
# [172]	valid_0's binary_logloss: 0.00310121
# [173]	valid_0's binary_logloss: 0.00310042
# [174]	valid_0's binary_logloss: 0.00309902
# [175]	valid_0's binary_logloss: 0.00309825
# [176]	valid_0's binary_logloss: 0.00309687
# [177]	valid_0's binary_logloss: 0.00309563
# [178]	valid_0's binary_logloss: 0.00309487
# [179]	valid_0's binary_logloss: 0.00309345
# [180]	valid_0's binary_logloss: 0.00309264
# [181]	valid_0's binary_logloss: 0.0030913
# [182]	valid_0's binary_logloss: 0.0030905
# [183]	valid_0's binary_logloss: 0.00308984
# [184]	valid_0's binary_logloss: 0.00308846
# [185]	valid_0's binary_logloss: 0.00308767
# [186]	valid_0's binary_logloss: 0.0030863
# [187]	valid_0's binary_logloss: 0.00308559
# [188]	valid_0's binary_logloss: 0.00308423
# [189]	valid_0's binary_logloss: 0.00308362
# [190]	valid_0's binary_logloss: 0.00308285
# [191]	valid_0's binary_logloss: 0.00308151
# [192]	valid_0's binary_logloss: 0.00308089
# [193]	valid_0's binary_logloss: 0.00307956
# [194]	valid_0's binary_logloss: 0.00307882
# [195]	valid_0's binary_logloss: 0.00307774
# [196]	valid_0's binary_logloss: 0.00307643
# [197]	valid_0's binary_logloss: 0.00307578
# [198]	valid_0's binary_logloss: 0.00307453
# [199]	valid_0's binary_logloss: 0.0030738
# [200]	valid_0's binary_logloss: 0.00307254
# [201]	valid_0's binary_logloss: 0.00307133
# [202]	valid_0's binary_logloss: 0.00307079
# [203]	valid_0's binary_logloss: 0.00307009
# [204]	valid_0's binary_logloss: 0.00306887
# [205]	valid_0's binary_logloss: 0.00306818
# [206]	valid_0's binary_logloss: 0.00306757
# [207]	valid_0's binary_logloss: 0.00306693
# [208]	valid_0's binary_logloss: 0.00306576
# [209]	valid_0's binary_logloss: 0.00306475
# [210]	valid_0's binary_logloss: 0.00306408
# [211]	valid_0's binary_logloss: 0.00306322
# [212]	valid_0's binary_logloss: 0.00306241
# [213]	valid_0's binary_logloss: 0.00306157
# [214]	valid_0's binary_logloss: 0.0030604
# [215]	valid_0's binary_logloss: 0.00305925
# [216]	valid_0's binary_logloss: 0.00305809
# [217]	valid_0's binary_logloss: 0.00305708
# [218]	valid_0's binary_logloss: 0.00305591
# [219]	valid_0's binary_logloss: 0.00305572
# [220]	valid_0's binary_logloss: 0.00305495
# [221]	valid_0's binary_logloss: 0.00305476
# [222]	valid_0's binary_logloss: 0.00305418
# [223]	valid_0's binary_logloss: 0.00305363
# [224]	valid_0's binary_logloss: 0.00305351
# [225]	valid_0's binary_logloss: 0.00305239
# [226]	valid_0's binary_logloss: 0.00305141
# [227]	valid_0's binary_logloss: 0.00305081
# [228]	valid_0's binary_logloss: 0.00304967
# [229]	valid_0's binary_logloss: 0.00304874
# [230]	valid_0's binary_logloss: 0.00304766
# [231]	valid_0's binary_logloss: 0.00304651
# [232]	valid_0's binary_logloss: 0.00304612
# [233]	valid_0's binary_logloss: 0.00304513
# [234]	valid_0's binary_logloss: 0.00304475
# [235]	valid_0's binary_logloss: 0.00304459
# [236]	valid_0's binary_logloss: 0.00304406
# [237]	valid_0's binary_logloss: 0.00304355
# [238]	valid_0's binary_logloss: 0.00304298
# [239]	valid_0's binary_logloss: 0.00304202
# [240]	valid_0's binary_logloss: 0.00304151
# [241]	valid_0's binary_logloss: 0.00304044
# [242]	valid_0's binary_logloss: 0.00303949
# [243]	valid_0's binary_logloss: 0.00303896
# [244]	valid_0's binary_logloss: 0.0030379
# [245]	valid_0's binary_logloss: 0.00303687
# [246]	valid_0's binary_logloss: 0.00303556
# [247]	valid_0's binary_logloss: 0.00303502
# [248]	valid_0's binary_logloss: 0.00303451
# [249]	valid_0's binary_logloss: 0.00303345
# [250]	valid_0's binary_logloss: 0.00303239
# [251]	valid_0's binary_logloss: 0.00303112
# [252]	valid_0's binary_logloss: 0.00303092
# [253]	valid_0's binary_logloss: 0.00303042
# [254]	valid_0's binary_logloss: 0.0030299
# [255]	valid_0's binary_logloss: 0.00302886
# [256]	valid_0's binary_logloss: 0.00302784
# [257]	valid_0's binary_logloss: 0.00302657
# [258]	valid_0's binary_logloss: 0.00302607
# [259]	valid_0's binary_logloss: 0.00302559
# [260]	valid_0's binary_logloss: 0.00302457
# [261]	valid_0's binary_logloss: 0.00302386
# [262]	valid_0's binary_logloss: 0.00302339
# [263]	valid_0's binary_logloss: 0.0030229
# [264]	valid_0's binary_logloss: 0.0030219
# [265]	valid_0's binary_logloss: 0.0030212
# [266]	valid_0's binary_logloss: 0.00302072
# [267]	valid_0's binary_logloss: 0.00302026
# [268]	valid_0's binary_logloss: 0.00301979
# [269]	valid_0's binary_logloss: 0.00301878
# [270]	valid_0's binary_logloss: 0.00301781
# [271]	valid_0's binary_logloss: 0.0030166
# [272]	valid_0's binary_logloss: 0.00301614
# [273]	valid_0's binary_logloss: 0.00301515
# [274]	valid_0's binary_logloss: 0.00301448
# [275]	valid_0's binary_logloss: 0.00301404
# [276]	valid_0's binary_logloss: 0.00301357
# [277]	valid_0's binary_logloss: 0.00301258
# [278]	valid_0's binary_logloss: 0.00301163
# [279]	valid_0's binary_logloss: 0.00301044
# [280]	valid_0's binary_logloss: 0.00301
# [281]	valid_0's binary_logloss: 0.00300955
# [282]	valid_0's binary_logloss: 0.00300858
# [283]	valid_0's binary_logloss: 0.00300796
# [284]	valid_0's binary_logloss: 0.00300757
# [285]	valid_0's binary_logloss: 0.00300712
# [286]	valid_0's binary_logloss: 0.00300617
# [287]	valid_0's binary_logloss: 0.00300597
# [288]	valid_0's binary_logloss: 0.00300503
# [289]	valid_0's binary_logloss: 0.00300388
# [290]	valid_0's binary_logloss: 0.00300344
# [291]	valid_0's binary_logloss: 0.0030025
# [292]	valid_0's binary_logloss: 0.0030019
# [293]	valid_0's binary_logloss: 0.00300147
# [294]	valid_0's binary_logloss: 0.00300053
# [295]	valid_0's binary_logloss: 0.0029994
# [296]	valid_0's binary_logloss: 0.00299899
# [297]	valid_0's binary_logloss: 0.00299856
# [298]	valid_0's binary_logloss: 0.00299763
# [299]	valid_0's binary_logloss: 0.00299671
# [300]	valid_0's binary_logloss: 0.00299653
# [301]	valid_0's binary_logloss: 0.00299559
# [302]	valid_0's binary_logloss: 0.0029945
# [303]	valid_0's binary_logloss: 0.00299393
# [304]	valid_0's binary_logloss: 0.00299352
# [305]	valid_0's binary_logloss: 0.00299311
# [306]	valid_0's binary_logloss: 0.0029922
# [307]	valid_0's binary_logloss: 0.00299128
# [308]	valid_0's binary_logloss: 0.00299019
# [309]	valid_0's binary_logloss: 0.00298985
# [310]	valid_0's binary_logloss: 0.00298945
# [311]	valid_0's binary_logloss: 0.00298854
# [312]	valid_0's binary_logloss: 0.00298764
# [313]	valid_0's binary_logloss: 0.00298738
# [314]	valid_0's binary_logloss: 0.00298698
# [315]	valid_0's binary_logloss: 0.00298659
# [316]	valid_0's binary_logloss: 0.00298621
# [317]	valid_0's binary_logloss: 0.00298576
# [318]	valid_0's binary_logloss: 0.00298508
# [319]	valid_0's binary_logloss: 0.00298463
# [320]	valid_0's binary_logloss: 0.00298439
# [321]	valid_0's binary_logloss: 0.00298414
# [322]	valid_0's binary_logloss: 0.00298375
# [323]	valid_0's binary_logloss: 0.00298337
# [324]	valid_0's binary_logloss: 0.00298299
# [325]	valid_0's binary_logloss: 0.00298211
# [326]	valid_0's binary_logloss: 0.00298121
# [327]	valid_0's binary_logloss: 0.00298016
# [328]	valid_0's binary_logloss: 0.00297979
# [329]	valid_0's binary_logloss: 0.00297942
# [330]	valid_0's binary_logloss: 0.00297899
# [331]	valid_0's binary_logloss: 0.00297855
# [332]	valid_0's binary_logloss: 0.00297831
# [333]	valid_0's binary_logloss: 0.00297766
# ...
# [1708]	valid_0's binary_logloss: 0.00215056
# [1709]	valid_0's binary_logloss: 0.00215021
# [1710]	valid_0's binary_logloss: 0.00215057
# [1711]	valid_0's binary_logloss: 0.00215017
# [1712]	valid_0's binary_logloss: 0.00215006
# [1713]	valid_0's binary_logloss: 0.0021504
# [1714]	valid_0's binary_logloss: 0.00215005
# [1715]	valid_0's binary_logloss: 0.00215
# [1716]	valid_0's binary_logloss: 0.00215024
# [1717]	valid_0's binary_logloss: 0.00215062
# [1718]	valid_0's binary_logloss: 0.00215077
# [1719]	valid_0's binary_logloss: 0.00215075
# [1720]	valid_0's binary_logloss: 0.00215064
# [1721]	valid_0's binary_logloss: 0.00215081
# [1722]	valid_0's binary_logloss: 0.00215096
# [1723]	valid_0's binary_logloss: 0.00215099
# [1724]	valid_0's binary_logloss: 0.00215107
# [1725]	valid_0's binary_logloss: 0.00215156
# [1726]	valid_0's binary_logloss: 0.00215145
# [1727]	valid_0's binary_logloss: 0.00215153
# [1728]	valid_0's binary_logloss: 0.00215202
# [1729]	valid_0's binary_logloss: 0.00215191
# [1730]	valid_0's binary_logloss: 0.00215249
# [1731]	valid_0's binary_logloss: 0.00215225
# [1732]	valid_0's binary_logloss: 0.00215274
# [1733]	valid_0's binary_logloss: 0.00215262
# [1734]	valid_0's binary_logloss: 0.0021527
# [1735]	valid_0's binary_logloss: 0.00215305
# [1736]	valid_0's binary_logloss: 0.00215294
# [1737]	valid_0's binary_logloss: 0.00215293
# [1738]	valid_0's binary_logloss: 0.00215301
# [1739]	valid_0's binary_logloss: 0.00215312
# [1740]	valid_0's binary_logloss: 0.00215311
# [1741]	valid_0's binary_logloss: 0.00215334
# [1742]	valid_0's binary_logloss: 0.00215332
# [1743]	valid_0's binary_logloss: 0.0021534
# [1744]	valid_0's binary_logloss: 0.00215328
# [1745]	valid_0's binary_logloss: 0.00215331
# [1746]	valid_0's binary_logloss: 0.00215319
# [1747]	valid_0's binary_logloss: 0.00215327
# [1748]	valid_0's binary_logloss: 0.00215351
# [1749]	valid_0's binary_logloss: 0.00215386
# [1750]	valid_0's binary_logloss: 0.00215397
# [1751]	valid_0's binary_logloss: 0.00215419
# [1752]	valid_0's binary_logloss: 0.00215418
# [1753]	valid_0's binary_logloss: 0.00215429
# [1754]	valid_0's binary_logloss: 0.00215437
# [1755]	valid_0's binary_logloss: 0.00215436
# [1756]	valid_0's binary_logloss: 0.00215444
# [1757]	valid_0's binary_logloss: 0.00215429
# [1758]	valid_0's binary_logloss: 0.00215416
# [1759]	valid_0's binary_logloss: 0.00215473
# [1760]	valid_0's binary_logloss: 0.00215459
# [1761]	valid_0's binary_logloss: 0.00215468
# [1762]	valid_0's binary_logloss: 0.00215467
# [1763]	valid_0's binary_logloss: 0.00215454
# [1764]	valid_0's binary_logloss: 0.00215465
# [1765]	valid_0's binary_logloss: 0.002155
# [1766]	valid_0's binary_logloss: 0.00215489
# [1767]	valid_0's binary_logloss: 0.00215488
# [1768]	valid_0's binary_logloss: 0.00215452
# [1769]	valid_0's binary_logloss: 0.00215509
# [1770]	valid_0's binary_logloss: 0.0021552
# [1771]	valid_0's binary_logloss: 0.00215476
# [1772]	valid_0's binary_logloss: 0.00215484
# [1773]	valid_0's binary_logloss: 0.00215483
# [1774]	valid_0's binary_logloss: 0.00215448
# [1775]	valid_0's binary_logloss: 0.00215504
# [1776]	valid_0's binary_logloss: 0.00215516
# [1777]	valid_0's binary_logloss: 0.00215504
# [1778]	valid_0's binary_logloss: 0.0021546
# [1779]	valid_0's binary_logloss: 0.00215458
# [1780]	valid_0's binary_logloss: 0.00215445
# [1781]	valid_0's binary_logloss: 0.00215481
# [1782]	valid_0's binary_logloss: 0.00215437
# [1783]	valid_0's binary_logloss: 0.00215403
# [1784]	valid_0's binary_logloss: 0.00215368
# [1785]	valid_0's binary_logloss: 0.00215324
# [1786]	valid_0's binary_logloss: 0.00215317
# [1787]	valid_0's binary_logloss: 0.00215316
# [1788]	valid_0's binary_logloss: 0.00215302
# [1789]	valid_0's binary_logloss: 0.00215295
# [1790]	valid_0's binary_logloss: 0.00215262
# [1791]	valid_0's binary_logloss: 0.00215297
# [1792]	valid_0's binary_logloss: 0.00215284
# [1793]	valid_0's binary_logloss: 0.00215281
# [1794]	valid_0's binary_logloss: 0.00215316
# [1795]	valid_0's binary_logloss: 0.00215304
# [1796]	valid_0's binary_logloss: 0.00215303
# [1797]	valid_0's binary_logloss: 0.00215261
# [1798]	valid_0's binary_logloss: 0.00215247
# [1799]	valid_0's binary_logloss: 0.00215282
# [1800]	valid_0's binary_logloss: 0.0021527
# [1801]	valid_0's binary_logloss: 0.00215274
# [1802]	valid_0's binary_logloss: 0.002153
# [1803]	valid_0's binary_logloss: 0.00215261
# [1804]	valid_0's binary_logloss: 0.00215245
# [1805]	valid_0's binary_logloss: 0.00215233
# [1806]	valid_0's binary_logloss: 0.00215268
# [1807]	valid_0's binary_logloss: 0.00215256
# [1808]	valid_0's binary_logloss: 0.00215253
# [1809]	valid_0's binary_logloss: 0.00215279
# [1810]	valid_0's binary_logloss: 0.00215265
# [1811]	valid_0's binary_logloss: 0.00215232
# [1812]	valid_0's binary_logloss: 0.00215217
# [1813]	valid_0's binary_logloss: 0.00215251
# [1814]	valid_0's binary_logloss: 0.00215285
# [1815]	valid_0's binary_logloss: 0.00215273
# [1816]	valid_0's binary_logloss: 0.00215276
# [1817]	valid_0's binary_logloss: 0.00215302
# [1818]	valid_0's binary_logloss: 0.0021529
# [1819]	valid_0's binary_logloss: 0.00215257
# [1820]	valid_0's binary_logloss: 0.00215261
# [1821]	valid_0's binary_logloss: 0.00215249
# [1822]	valid_0's binary_logloss: 0.00215283
# [1823]	valid_0's binary_logloss: 0.00215283
# [1824]	valid_0's binary_logloss: 0.00215286
# [1825]	valid_0's binary_logloss: 0.00215274
# [1826]	valid_0's binary_logloss: 0.00215273
# [1827]	valid_0's binary_logloss: 0.00215277
# [1828]	valid_0's binary_logloss: 0.0021531
# [1829]	valid_0's binary_logloss: 0.00215278
# [1830]	valid_0's binary_logloss: 0.0021529
# [1831]	valid_0's binary_logloss: 0.00215329
# [1832]	valid_0's binary_logloss: 0.00215317
# [1833]	valid_0's binary_logloss: 0.0021532
# [1834]	valid_0's binary_logloss: 0.00215333
# [1835]	valid_0's binary_logloss: 0.0021532
# [1836]	valid_0's binary_logloss: 0.00215319
# [1837]	valid_0's binary_logloss: 0.00215283
# [1838]	valid_0's binary_logloss: 0.00215317
# [1839]	valid_0's binary_logloss: 0.0021531
# [1840]	valid_0's binary_logloss: 0.00215297
# [1841]	valid_0's binary_logloss: 0.00215265
# [1842]	valid_0's binary_logloss: 0.00215258
# [1843]	valid_0's binary_logloss: 0.00215246
# [1844]	valid_0's binary_logloss: 0.00215244
# [1845]	valid_0's binary_logloss: 0.00215238
# [1846]	valid_0's binary_logloss: 0.00215225
# [1847]	valid_0's binary_logloss: 0.0021519
# [1848]	valid_0's binary_logloss: 0.002152
# [1849]	valid_0's binary_logloss: 0.00215225
# [1850]	valid_0's binary_logloss: 0.00215212
# [1851]	valid_0's binary_logloss: 0.00215206
# [1852]	valid_0's binary_logloss: 0.00215189
# [1853]	valid_0's binary_logloss: 0.00215152
# [1854]	valid_0's binary_logloss: 0.0021514
# [1855]	valid_0's binary_logloss: 0.00215105
# [1856]	valid_0's binary_logloss: 0.00215106
# [1857]	valid_0's binary_logloss: 0.00215089
# [1858]	valid_0's binary_logloss: 0.0021509
# [1859]	valid_0's binary_logloss: 0.00215101
# [1860]	valid_0's binary_logloss: 0.00215125
# [1861]	valid_0's binary_logloss: 0.00215093
# [1862]	valid_0's binary_logloss: 0.00215104
# [1863]	valid_0's binary_logloss: 0.00215128
# [1864]	valid_0's binary_logloss: 0.00215116
# [1865]	valid_0's binary_logloss: 0.00215117
# [1866]	valid_0's binary_logloss: 0.002151
# Early stopping, best iteration is:
# [1666]	valid_0's binary_logloss: 0.00214662
# Training Log Loss:  4.064338461829422e-08
# CV Log Loss:  0.002146617027649916
# [1]	valid_0's binary_logloss: 0.00296896
# Training until validation scores don't improve for 200 rounds.
# [2]	valid_0's binary_logloss: 0.00146002
# [3]	valid_0's binary_logloss: 0.00085474
# [4]	valid_0's binary_logloss: 0.00162272
# [5]	valid_0's binary_logloss: 0.0016146
# [6]	valid_0's binary_logloss: 0.00162016
# [7]	valid_0's binary_logloss: 0.00160755
# [8]	valid_0's binary_logloss: 0.00162071
# [9]	valid_0's binary_logloss: 0.0016217
# [10]	valid_0's binary_logloss: 0.00161123
# [11]	valid_0's binary_logloss: 0.00160145
# [12]	valid_0's binary_logloss: 0.0015921
# [13]	valid_0's binary_logloss: 0.00158301
# [14]	valid_0's binary_logloss: 0.00159453
# [15]	valid_0's binary_logloss: 0.00158493
# [16]	valid_0's binary_logloss: 0.00157664
# [17]	valid_0's binary_logloss: 0.00156699
# [18]	valid_0's binary_logloss: 0.00155602
# [19]	valid_0's binary_logloss: 0.00154513
# [20]	valid_0's binary_logloss: 0.00153703
# [21]	valid_0's binary_logloss: 0.00152817
# [22]	valid_0's binary_logloss: 0.00151986
# [23]	valid_0's binary_logloss: 0.00151177
# [24]	valid_0's binary_logloss: 0.00150585
# [25]	valid_0's binary_logloss: 0.00149966
# [26]	valid_0's binary_logloss: 0.00149348
# [27]	valid_0's binary_logloss: 0.00148759
# [28]	valid_0's binary_logloss: 0.00148171
# [29]	valid_0's binary_logloss: 0.00147594
# [30]	valid_0's binary_logloss: 0.00147041
# [31]	valid_0's binary_logloss: 0.00146485
# [32]	valid_0's binary_logloss: 0.00145945
# [33]	valid_0's binary_logloss: 0.00145418
# [34]	valid_0's binary_logloss: 0.00144912
# [35]	valid_0's binary_logloss: 0.00144403
# [36]	valid_0's binary_logloss: 0.00143932
# [37]	valid_0's binary_logloss: 0.0014344
# [38]	valid_0's binary_logloss: 0.0014297
# [39]	valid_0's binary_logloss: 0.00142499
# [40]	valid_0's binary_logloss: 0.00142046
# [41]	valid_0's binary_logloss: 0.00141589
# [42]	valid_0's binary_logloss: 0.00141147
# [43]	valid_0's binary_logloss: 0.00140716
# [44]	valid_0's binary_logloss: 0.00140268
# [45]	valid_0's binary_logloss: 0.00139855
# [46]	valid_0's binary_logloss: 0.0013945
# [47]	valid_0's binary_logloss: 0.00139053
# [48]	valid_0's binary_logloss: 0.00138655
# [49]	valid_0's binary_logloss: 0.00138273
# [50]	valid_0's binary_logloss: 0.00137891
# [51]	valid_0's binary_logloss: 0.00137523
# [52]	valid_0's binary_logloss: 0.00137162
# [53]	valid_0's binary_logloss: 0.00136801
# [54]	valid_0's binary_logloss: 0.00136453
# [55]	valid_0's binary_logloss: 0.00136109
# [56]	valid_0's binary_logloss: 0.00135774
# [57]	valid_0's binary_logloss: 0.0013541
# [58]	valid_0's binary_logloss: 0.00135111
# [59]	valid_0's binary_logloss: 0.00134739
# [60]	valid_0's binary_logloss: 0.00134576
# [61]	valid_0's binary_logloss: 0.00134262
# [62]	valid_0's binary_logloss: 0.00133963
# [63]	valid_0's binary_logloss: 0.00133618
# [64]	valid_0's binary_logloss: 0.00133253
# [65]	valid_0's binary_logloss: 0.00132862
# [66]	valid_0's binary_logloss: 0.00132473
# [67]	valid_0's binary_logloss: 0.00132106
# [68]	valid_0's binary_logloss: 0.00131717
# [69]	valid_0's binary_logloss: 0.00131339
# [70]	valid_0's binary_logloss: 0.00130976
# [71]	valid_0's binary_logloss: 0.00130618
# [72]	valid_0's binary_logloss: 0.00130247
# [73]	valid_0's binary_logloss: 0.00129898
# [74]	valid_0's binary_logloss: 0.00129546
# [75]	valid_0's binary_logloss: 0.00129196
# [76]	valid_0's binary_logloss: 0.00128862
# [77]	valid_0's binary_logloss: 0.0012853
# [78]	valid_0's binary_logloss: 0.00128191
# [79]	valid_0's binary_logloss: 0.00128431
# [80]	valid_0's binary_logloss: 0.00128119
# [81]	valid_0's binary_logloss: 0.00127787
# [82]	valid_0's binary_logloss: 0.00127459
# [83]	valid_0's binary_logloss: 0.00127147
# [84]	valid_0's binary_logloss: 0.00126828
# [85]	valid_0's binary_logloss: 0.00126514
# [86]	valid_0's binary_logloss: 0.00126204
# [87]	valid_0's binary_logloss: 0.00125964
# [88]	valid_0's binary_logloss: 0.00125706
# [89]	valid_0's binary_logloss: 0.00125446
# [90]	valid_0's binary_logloss: 0.00125215
# [91]	valid_0's binary_logloss: 0.00124962
# [92]	valid_0's binary_logloss: 0.00124742
# [93]	valid_0's binary_logloss: 0.00124502
# [94]	valid_0's binary_logloss: 0.00124259
# [95]	valid_0's binary_logloss: 0.00124047
# [96]	valid_0's binary_logloss: 0.00123815
# [97]	valid_0's binary_logloss: 0.00123672
# [98]	valid_0's binary_logloss: 0.00123445
# [99]	valid_0's binary_logloss: 0.00123274
# [100]	valid_0's binary_logloss: 0.00123074
# [101]	valid_0's binary_logloss: 0.00122922
# [102]	valid_0's binary_logloss: 0.00122707
# [103]	valid_0's binary_logloss: 0.00122567
# [104]	valid_0's binary_logloss: 0.00122358
# [105]	valid_0's binary_logloss: 0.001222
# [106]	valid_0's binary_logloss: 0.00122004
# [107]	valid_0's binary_logloss: 0.00121718
# [108]	valid_0's binary_logloss: 0.00121547
# [109]	valid_0's binary_logloss: 0.00121382
# [110]	valid_0's binary_logloss: 0.00121165
# [111]	valid_0's binary_logloss: 0.00120989
# [112]	valid_0's binary_logloss: 0.00120829
# [113]	valid_0's binary_logloss: 0.00120644
# [114]	valid_0's binary_logloss: 0.00120424
# [115]	valid_0's binary_logloss: 0.00120268
# [116]	valid_0's binary_logloss: 0.00120115
# [117]	valid_0's binary_logloss: 0.00119856
# [118]	valid_0's binary_logloss: 0.00119669
# [119]	valid_0's binary_logloss: 0.00119517
# [120]	valid_0's binary_logloss: 0.0011933
# [121]	valid_0's binary_logloss: 0.0011915
# [122]	valid_0's binary_logloss: 0.00118998
# [123]	valid_0's binary_logloss: 0.00118846
# [124]	valid_0's binary_logloss: 0.00118683
# [125]	valid_0's binary_logloss: 0.00118544
# [126]	valid_0's binary_logloss: 0.00118352
# [127]	valid_0's binary_logloss: 0.0011822
# [128]	valid_0's binary_logloss: 0.0011799
# [129]	valid_0's binary_logloss: 0.00117831
# [130]	valid_0's binary_logloss: 0.00117667
# [131]	valid_0's binary_logloss: 0.00117528
# [132]	valid_0's binary_logloss: 0.00117393
# [133]	valid_0's binary_logloss: 0.00117215
# [134]	valid_0's binary_logloss: 0.00117098
# [135]	valid_0's binary_logloss: 0.00116966
# [136]	valid_0's binary_logloss: 0.00116793
# [137]	valid_0's binary_logloss: 0.00116678
# [138]	valid_0's binary_logloss: 0.00116518
# [139]	valid_0's binary_logloss: 0.00116408
# [140]	valid_0's binary_logloss: 0.00116263
# [141]	valid_0's binary_logloss: 0.00116141
# [142]	valid_0's binary_logloss: 0.00115989
# [143]	valid_0's binary_logloss: 0.00115874
# [144]	valid_0's binary_logloss: 0.00115733
# [145]	valid_0's binary_logloss: 0.0011562
# [146]	valid_0's binary_logloss: 0.00115438
# [147]	valid_0's binary_logloss: 0.00115325
# [148]	valid_0's binary_logloss: 0.00115184
# [149]	valid_0's binary_logloss: 0.00115088
# [150]	valid_0's binary_logloss: 0.00114936
# [151]	valid_0's binary_logloss: 0.00114833
# [152]	valid_0's binary_logloss: 0.00114743
# [153]	valid_0's binary_logloss: 0.00114605
# [154]	valid_0's binary_logloss: 0.00114491
# [155]	valid_0's binary_logloss: 0.00114391
# [156]	valid_0's binary_logloss: 0.00114212
# [157]	valid_0's binary_logloss: 0.0011413
# [158]	valid_0's binary_logloss: 0.0011399
# [159]	valid_0's binary_logloss: 0.00113897
# [160]	valid_0's binary_logloss: 0.00113781
# [161]	valid_0's binary_logloss: 0.00113688
# [162]	valid_0's binary_logloss: 0.0011361
# [163]	valid_0's binary_logloss: 0.00113478
# [164]	valid_0's binary_logloss: 0.00113403
# [165]	valid_0's binary_logloss: 0.00113284
# [166]	valid_0's binary_logloss: 0.00113197
# [167]	valid_0's binary_logloss: 0.00113127
# [168]	valid_0's binary_logloss: 0.00113002
# [169]	valid_0's binary_logloss: 0.00112919
# [170]	valid_0's binary_logloss: 0.00112806
# [171]	valid_0's binary_logloss: 0.0011274
# [172]	valid_0's binary_logloss: 0.00112584
# [173]	valid_0's binary_logloss: 0.00112509
# [174]	valid_0's binary_logloss: 0.0011241
# [175]	valid_0's binary_logloss: 0.00112337
# [176]	valid_0's binary_logloss: 0.00112233
# [177]	valid_0's binary_logloss: 0.00112163
# [178]	valid_0's binary_logloss: 0.00112106
# [179]	valid_0's binary_logloss: 0.00112002
# [180]	valid_0's binary_logloss: 0.00111905
# [181]	valid_0's binary_logloss: 0.0011177
# [182]	valid_0's binary_logloss: 0.00111712
# [183]	valid_0's binary_logloss: 0.00111579
# [184]	valid_0's binary_logloss: 0.00111525
# [185]	valid_0's binary_logloss: 0.00111462
# [186]	valid_0's binary_logloss: 0.00111332
# [187]	valid_0's binary_logloss: 0.00111279
# [188]	valid_0's binary_logloss: 0.00111152
# [189]	valid_0's binary_logloss: 0.00111026
# [190]	valid_0's binary_logloss: 0.00110977
# [191]	valid_0's binary_logloss: 0.00110919
# [192]	valid_0's binary_logloss: 0.00110872
# [193]	valid_0's binary_logloss: 0.0011075
# [194]	valid_0's binary_logloss: 0.00110706
# [195]	valid_0's binary_logloss: 0.0011059
# [196]	valid_0's binary_logloss: 0.00110536
# [197]	valid_0's binary_logloss: 0.00110418
# [198]	valid_0's binary_logloss: 0.00110376
# [199]	valid_0's binary_logloss: 0.00110265
# [200]	valid_0's binary_logloss: 0.00110214
# [201]	valid_0's binary_logloss: 0.00110031
# [202]	valid_0's binary_logloss: 0.00109993
# [203]	valid_0's binary_logloss: 0.00109881
# Early stopping, best iteration is:
# [3]	valid_0's binary_logloss: 0.00085474
# Training Log Loss:  0.0025909384521976956
# CV Log Loss:  0.0008547400469242218
# LightGBM Gradient Boosting Log Loss:  0.001613317295229834

# %% [markdown]
# ## **Precision-Recall Curve- Train**

# %%
preds, average_precision = plotResults(y_train, \
                        predictionsBasedOnKFolds.loc[:,'prediction'], True)

# %% [markdown]
# ## **Precision-Recall Curve- Test**

# %%
predictions = pd.Series(data=gbm.predict(X_test, \
                    num_iteration=gbm.best_iteration),index=X_test.index)
preds, average_precision = plotResults(y_test, predictions, True)

# %% [markdown]
# Finding the precision

# %%
preds, precision = precisionAnalysis(preds, "anomalyScore", 0.75)
print(precision)
# Out:
# 0.0013136394219986542

# %%
featuresImportance = pd.DataFrame(data=list(gbm.feature_importance()), \
                        index=X_train.columns,columns=['featImportance'])
featuresImportance = featuresImportance/featuresImportance.sum()
featuresImportance.sort_values(by='featImportance', \
                               ascending=False,inplace=True)
featuresImportance
# Out:
#      featImportance
# 22         0.121212
# V7         0.090909
# V24        0.090909
# 31         0.090909
# V1         0.060606
# ..              ...
# 4          0.000000
# V2         0.000000
# 6          0.000000
# 7          0.000000
# 39         0.000000
#
# [69 rows x 1 columns]

# %%
featuresImportance.shape
# Out:
# (69, 1)
